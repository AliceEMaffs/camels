# %% [markdown]
# # Quick script to search directories of models and plots (with metrics) to find best current model configs.

# %%
#!/usr/bin/env python
import os
import re
import json
import glob
import numpy as np
import pandas as pd
import pickle
# add validation loss.
from pprint import pprint

sim_set = "LH"
snap_str = "044"
pam_num = "6pams"
model_dir = os.path.join(f"/disk/xray15/aem2/data/{pam_num}/{sim_set}/IllustrisTNG/models/colours_lfs/{snap_str}")
plots_dir = os.path.join(f"/disk/xray15/aem2/plots/{pam_num}/{sim_set}/IllustrisTNG/test/sbi_plots/colours_lfs/{snap_str}")


print(model_dir)
print(plots_dir)

# Set display options for full DataFrame visibility
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 1000)


def find_best_model_with_metrics(model_dir, plots_dir):
    """
    Find the best model by examining all pickle files in the model directory,
    comparing their validation losses, and incorporating metrics data from plots_dir.
    
    Args:
        model_dir: Directory containing model files
        plots_dir: Directory containing metrics files
        
    Returns:
        DataFrame with model info sorted by validation loss
    """
    print(f"Searching for models in: {model_dir}")
    print(f"Looking for metrics in: {plots_dir}")
    
    # List to store model information
    model_info = []
    
    # Find all complete.pkl files in subdirectories
    for root, dirs, files in os.walk(model_dir):
        for file in files:
            if file.endswith('.pkl') and 'complete' in file and not file.endswith('_posterior.pkl'):
                file_path = os.path.join(root, file)
                model_name = os.path.basename(root)
                
                try:
                    # Load the pickle file
                    with open(file_path, 'rb') as f:
                        data = pickle.load(f)
                    
                    # Extract validation loss from the summaries
                    val_loss = None
                    if isinstance(data, dict) and 'summaries' in data:
                        summaries = data['summaries']
                        
                        # Check format of summaries - could be list or dict
                        if isinstance(summaries, list) and len(summaries) > 0:
                            # If it's a list, look at each item
                            for summary in summaries:
                                if 'validation_log_probs' in summary:
                                    # Get the maximum validation log probability (best performance)
                                    val_probs = summary['validation_log_probs']
                                    if val_probs:
                                        val_loss = max(val_probs)
                        elif isinstance(summaries, dict):
                            if 'validation_log_probs' in summaries:
                                val_probs = summaries['validation_log_probs']
                                if val_probs:
                                    val_loss = max(val_probs)
                    
                    # Parse model parameters from directory name
                    params = {}
                    parts = model_name.split('_')
                    for part in parts:
                        if 'batch' in part:
                            params['batch_size'] = part.replace('batch', '')
                        elif 'lr' in part:
                            params['learning_rate'] = part.replace('lr', '')
                        elif 'epochs' in part and 'max' not in part:
                            params['epochs'] = part.replace('epochs', '')
                        elif 'max_num_epochs' in part:
                            params['max_epochs'] = part.replace('max_num_epochs', '')
                        elif 'h' in part and len(part) < 5:  # Avoid matching things like "hidden"
                            params['hidden_size'] = part.replace('h', '')
                        elif 't' in part and len(part) < 5:  # Avoid matching words with 't'
                            params['transforms'] = part.replace('t', '')
                        elif 'nn' in part:
                            params['num_nets'] = part.replace('nn', '')
                    
                    # Add to our list
                    model_info.append({
                        'model_dir': root,
                        'model_file': file,
                        'model_name': model_name,
                        'val_loss': val_loss,
                        **params
                    })
                    
                except Exception as e:
                    print(f"Error processing {file_path}: {e}")
    
    # Convert to DataFrame
    if model_info:
        df_models = pd.DataFrame(model_info)
        
        # Sort by validation loss (highest is best for log probabilities)
        if 'val_loss' in df_models.columns:
            df_models = df_models.sort_values('val_loss', ascending=False)
        
        # Now find and parse metrics files in the plots directory
        metrics_data = []
        metrics_files = glob.glob(os.path.join(plots_dir, "**", "metrics_*.txt"), recursive=True)
        
        print(f"Found {len(metrics_files)} metrics files in plots directory.")
        
        for metrics_file in metrics_files:
            metrics_dict, config = parse_metrics_file(metrics_file)
            if metrics_dict:
                # Create a row for each parameter
                for i, param in enumerate(metrics_dict['parameters']):
                    metrics_data.append({
                        'model_name': config,
                        'parameter': param,
                        'R²': metrics_dict['R²'][i] if i < len(metrics_dict['R²']) else None,
                        'RMSE': metrics_dict['RMSE'][i] if i < len(metrics_dict['RMSE']) else None
                    })
        
        # Convert metrics data to DataFrame
        if metrics_data:
            df_metrics = pd.DataFrame(metrics_data)
            
            # Pivot the metrics DataFrame to have one row per model with columns for each parameter's metrics
            df_metrics_pivoted = pd.pivot_table(
                df_metrics, 
                index='model_name', 
                columns='parameter', 
                values=['R²', 'RMSE']
            )
            
            # Flatten the column multi-index
            df_metrics_pivoted.columns = [f"{metric}_{param}" for metric, param in df_metrics_pivoted.columns]
            df_metrics_pivoted = df_metrics_pivoted.reset_index()
            
            # Merge model info with metrics
            df_combined = pd.merge(
                df_models, 
                df_metrics_pivoted, 
                left_on='model_name', 
                right_on='model_name', 
                how='left'
            )
            
            return df_combined
        
        return df_models
    else:
        return pd.DataFrame()

def parse_metrics_file(file_path):
    """Parse a metrics file and extract R² and RMSE for each parameter."""
    # Extract configuration from file path
    config_match = re.search(r'/([^/]+)/metrics_', file_path)
    config = config_match.group(1) if config_match else os.path.basename(os.path.dirname(file_path))
    
    # Parse the metrics file
    metrics_dict = {
        'config': config,
        'parameters': [],
        'R²': [],
        'RMSE': []
    }
    
    try:
        with open(file_path, 'r') as f:
            lines = f.readlines()
            
        param_pattern = re.compile(r'Metrics for (.*):')
        r2_pattern = re.compile(r'R²: ([-]?\d+\.\d+)')
        rmse_pattern = re.compile(r'RMSE: (\d+\.\d+)')
        
        current_param = None
        
        for line in lines:
            param_match = param_pattern.search(line)
            if param_match:
                current_param = param_match.group(1)
                metrics_dict['parameters'].append(current_param)
                continue
                
            if current_param:
                r2_match = r2_pattern.search(line)
                if r2_match:
                    metrics_dict['R²'].append(float(r2_match.group(1)))
                    
                rmse_match = rmse_pattern.search(line)
                if rmse_match:
                    metrics_dict['RMSE'].append(float(rmse_match.group(1)))
        
        return metrics_dict, config
    
    except Exception as e:
        print(f"Error parsing {file_path}: {e}")
        return None, config

# Execute the function
df_combined = find_best_model_with_metrics(model_dir, plots_dir)

# Display results
if not df_combined.empty:
    pd.set_option('display.max_columns', None)  # Show all columns
    pd.set_option('display.max_rows', None)     # Show all rows
    print("\nModel Comparison (sorted by validation loss):")
    print(df_combined)
    
    # Find the best model
    if 'val_loss' in df_combined.columns and not df_combined['val_loss'].isna().all():
        best_model = df_combined.iloc[0]
        print(f"\nBest model found:")
        print(f"Directory: {best_model['model_dir']}")
        print(f"File: {best_model['model_file']}")
        print(f"Validation loss: {best_model['val_loss']}")
        
        # Get model parameters
        params_str = []
        for param in ['batch_size', 'learning_rate', 'hidden_size', 'transforms', 'num_nets', 'epochs', 'max_epochs']:
            if param in best_model and not pd.isna(best_model[param]):
                params_str.append(f"{param}={best_model[param]}")
        
        print(f"Parameters: {', '.join(params_str)}")
        
        # Print metrics for best model if available
        metrics_cols = [col for col in best_model.index if 'R²_' in col or 'RMSE_' in col]
        if metrics_cols:
            print("\nMetrics for best model:")
            for col in metrics_cols:
                if not pd.isna(best_model[col]):
                    print(f"{col}: {best_model[col]}")
    else:
        print("\nNo validation loss information found in any models.")
else:
    print("\nNo model files found.")

# If you want to save the results
results_path = os.path.join(plots_dir, "model_comparison_with_metrics.csv")
if not df_combined.empty:
    df_combined.to_csv(results_path, index=False)
    print(f"\nResults saved to: {results_path}")
# Out:
# /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044
# /disk/xray15/aem2/plots/6pams/LH/IllustrisTNG/test/sbi_plots/colours_lfs/044
# Searching for models in: /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044
# Looking for metrics in: /disk/xray15/aem2/plots/6pams/LH/IllustrisTNG/test/sbi_plots/colours_lfs/044
# Found 7 metrics files in plots directory.
#
# Model Comparison (sorted by validation loss):
#                                                                                                                                                             model_dir                                           model_file                                                                                     model_name  val_loss batch_size learning_rate epochs hidden_size transforms num_nets  RMSE_$A_{\mathrm{AGN1}}$  RMSE_$A_{\mathrm{AGN2}}$  RMSE_$A_{\mathrm{SN1}}$  RMSE_$A_{\mathrm{SN2}}$  RMSE_$\Omega_m$  RMSE_$\sigma_8$  R²_$A_{\mathrm{AGN1}}$  R²_$A_{\mathrm{AGN2}}$  R²_$A_{\mathrm{SN1}}$  R²_$A_{\mathrm{SN2}}$  R²_$\Omega_m$  R²_$\sigma_8$
# 0   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  3.256308          5        0.0004    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 1   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  3.235912          5        0.0006    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 2   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  3.185747          4        0.0004    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 3     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t5_nn3  3.110337          5        0.0004    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 4   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  3.095100          5        0.0004    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 5   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t6_nn3  3.082522          5        0.0005    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 6   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  3.065853          4        0.0005    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 7   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  3.065129          4        0.0005    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 8   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  3.055519          4        0.0006    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 9   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t6_nn3  3.035183          5        0.0006    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 10    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t5_nn3  3.002461          5        0.0006    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 11  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t4_nn3  2.999062          5        0.0006    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 12  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  2.986480          5        0.0005    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 13  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  2.968965          4        0.0004    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 14  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  2.968931          5        0.0005    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 15  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t6_nn3  2.945992          5        0.0004    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 16  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  2.909082          4        0.0004    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 17  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t4_nn3  2.897458          4        0.0004    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 18  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t4_nn3  2.871828          5        0.0004    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 19  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t5_nn3  2.849933          5        0.0006    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 20    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t4_nn3  2.839515          5        0.0004    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 21  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  2.816462          5        0.0006    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 22  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  2.796494          5        0.0004    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 23    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t6_nn3  2.792928          5        0.0005    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 24  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t5_nn3  2.787676          5        0.0005    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 25  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  2.755641          4        0.0006    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 26    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h80_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h80_t4_nn2  2.744975          4        0.0005    100          80          4        2                    1.0817                    0.4690                   0.6448                   0.2199           0.0635           0.0628                 -0.1231                 -0.1779                 0.6777                 0.7550         0.7241         0.7450
# 27  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  2.741579          4        0.0005    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 28  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  2.718773          5        0.0005    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 29  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  2.710635          5        0.0006    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 30  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t6_nn3  2.684659          5        0.0006    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 31  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t4_nn3  2.680730          4        0.0006    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 32  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3  2.666023          4        0.0006    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 33  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t4_nn3  2.648518          5        0.0004    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 34  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t4_nn3  2.647849          5        0.0005    100          70          4        3                    1.0977                    0.4873                   0.5822                   0.2052           0.0585           0.0615                 -0.1565                 -0.2712                 0.7372                 0.7867         0.7658         0.7556
# 35  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  2.646160          4        0.0006    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 36    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t5_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t5_nn2  2.643378          4        0.0005    100          60          5        2                    1.0974                    0.4672                   0.5814                   0.2149           0.0599           0.0613                 -0.1560                 -0.1686                 0.7380                 0.7661         0.7539         0.7570
# 37    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t6_nn3  2.631104          5        0.0006    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 38  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  2.556097          5        0.0004    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 39  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t4_nn3  2.534312          4        0.0005    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 40  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t5_nn3  2.521637          5        0.0005    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 41    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t4_nn3  2.516804          5        0.0006    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 42   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t4_nn3  2.513308          4         5e-05    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 43  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  2.502876          4        0.0005    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 44     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h80_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h80_t4_nn2  2.492777          4         5e-05    100          80          4        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 45  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  2.471571          4        0.0005    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 46     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t4_nn3  2.469050          4         5e-05    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 47     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t5_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t5_nn2  2.435206          4         5e-05    100          60          5        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 48    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t4_nn3  2.430971          5        0.0005    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 49  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.9_h65_t3_nn3  2.429646          4        0.0004    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 50     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t5_nn3  2.400363          4         5e-05    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 51  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t5_nn3  2.399179          5        0.0006    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 52  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t5_nn3  2.398103          5        0.0004    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 53  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t4_nn3  2.348045          5        0.0004    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 54   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t5_nn3  2.347967          4         5e-05    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 55  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t4_nn3  2.334552          4        0.0004    100          65          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 56    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t5_nn3  2.319130          5        0.0005    100          70          5        3                    1.0893                    0.4905                   0.6007                   0.2122           0.0614           0.0623                 -0.1389                 -0.2878                 0.7202                 0.7719         0.7414         0.7489
# 57  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h70_t6_nn3  2.318724          5        0.0004    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 58     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t4_nn2  2.286739          4         5e-05    100          60          4        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 59  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t4_nn3  2.286461          5        0.0006    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 60    /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl    batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2_h70_t6_nn3  2.253160          5        0.0004    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 61  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t5_nn3  2.247860          5        0.0004    100          70          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 62   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t4_nn2  2.220463          4         5e-05    100          70          4        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 63      /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs5_max_num_epochs20_validation_fraction0.1_clip_max_norm1_h60_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl      batch4_lr0.0005_epochs5_max_num_epochs20_validation_fraction0.1_clip_max_norm1_h60_t4_nn2  2.216582          4        0.0005     20          60          4        2                    1.1103                    0.4648                   0.5962                   0.2126           0.0633           0.0609                 -0.1831                 -0.1567                 0.7245                 0.7711         0.7258         0.7597
# 64  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t4_nn3  2.188468          5        0.0005    100          70          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 65  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch4_lr0.0006_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.7_h65_t3_nn3  2.183930          4        0.0006    100          65          3        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 66                     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs5_max_num_epochs20_validation_fraction0.1_h60_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl                     batch4_lr0.0005_epochs5_max_num_epochs20_validation_fraction0.1_h60_t4_nn2  2.181032          4        0.0005     20          60          4        2                    1.0951                    0.4680                   0.5546                   0.2193           0.0585           0.0628                 -0.1511                 -0.1726                 0.7616                 0.7564         0.7660         0.7447
# 67  /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t6_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl  batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm2.2_h70_t6_nn3  2.177484          5        0.0005    100          70          6        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 68   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t5_nn3  2.123630          4         5e-05    100          60          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 69   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t4_nn2  2.026999          4         5e-05    100          60          4        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 70                   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_h60_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl                   batch4_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_h60_t4_nn2  2.023605          4        0.0005    100          60          4        2                    1.0750                    0.4823                   0.5669                   0.2119           0.0585           0.0606                 -0.1091                 -0.2456                 0.7508                 0.7726         0.7657         0.7622
# 71     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t4_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t4_nn2  2.001570          4         5e-05    100          70          4        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 72   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t4_nn3  1.917367          4         5e-05    100          60          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 73     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t4_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t4_nn3  1.872519          4         5e-05    100          60          4        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 74   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t5_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h70_t5_nn2  1.784069          4         5e-05    100          70          5        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 75   /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t5_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl   batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm0.5_h60_t5_nn2  1.737565          4         5e-05    100          60          5        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 76     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t5_nn2  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h70_t5_nn2  1.716822          4         5e-05    100          70          5        2                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
# 77     /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t5_nn3  IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl     batch4_lr5e-05_epochs15_max_num_epochs100_validation_fraction0.1_clip_max_norm1_h60_t5_nn3  1.081754          4         5e-05    100          60          5        3                       NaN                       NaN                      NaN                      NaN              NaN              NaN                     NaN                     NaN                    NaN                    NaN            NaN            NaN
#
# Best model found:
# Directory: /disk/xray15/aem2/data/6pams/LH/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0004_epochs20_max_num_epochs100_validation_fraction0.1_clip_max_norm1.8_h65_t3_nn3
# File: IllustrisTNG_all_BC03_attenuated_13_13_complete.pkl
# Validation loss: 3.25630751185947
# Parameters: batch_size=5, learning_rate=0.0004, hidden_size=65, transforms=3, num_nets=3, epochs=100
#
# Metrics for best model:
#
# Results saved to: /disk/xray15/aem2/plots/6pams/LH/IllustrisTNG/test/sbi_plots/colours_lfs/044/model_comparison_with_metrics.csv

# %%
# SB best: /disk/xray15/aem2/data/28pams/SB/IllustrisTNG/models/colours_lfs/044/batch5_lr0.0005_epochs20_max_num_epochs100_validation_fraction0.1_h70_t4_nn3
