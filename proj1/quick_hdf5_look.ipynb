# %%
import h5py

def find_snap_groups(file_path):
    snap_groups = []

    def explore_group(group):
        for key in group.keys():
            item = group[key]
            if isinstance(item, h5py.Group):  # Check if it's a group
                if key.startswith("snap_"):
                    snap_groups.append(key)
                explore_group(item)  # Recursive call

    try:
        with h5py.File(file_path, 'r') as hdf_file:
            explore_group(hdf_file)
        return snap_groups
    except Exception as e:
        print(f"An error occurred while accessing the file: {e}")
        return []

# Replace this path with the correct path to your HDF5 file
file_path = "/home/jovyan/Data/Photometry/Swift-EAGLE/L25n256/1P/Swift-EAGLE_1P_p5_2_photometry.hdf5"
snap_groups = find_snap_groups(file_path)

if snap_groups:
    print(f"Found the following 'snap_' groups: {snap_groups}")
else:
    print("No 'snap_' groups found.")
# Out:
# Found the following 'snap_' groups: ['snap_086']

# %%
import h5py

def find_snap_groups(file_path):
    snap_groups = []

    def explore_group(group):
        for key in group.keys():
            item = group[key]
            if isinstance(item, h5py.Group):  # Check if it's a group
                if key.startswith("snap_"):
                    snap_groups.append(key)
                explore_group(item)  # Recursive call

    try:
        with h5py.File(file_path, 'r') as hdf_file:
            explore_group(hdf_file)
        return snap_groups
    except Exception as e:
        print(f"An error occurred while accessing the file: {e}")
        return []

# Replace this path with the correct path to your HDF5 file
file_path = "/home/jovyan/Data/Photometry/IllustrisTNG/L25n256/1P/IllustrisTNG_1P_p1_0_photometry.hdf5"
snap_groups = find_snap_groups(file_path)

if snap_groups:
    print(f"Found the following 'snap_' groups: {snap_groups}")
else:
    print("No 'snap_' groups found.")
# Out:
# Found the following 'snap_' groups: ['snap_014', 'snap_018', 'snap_024', 'snap_028', 'snap_032', 'snap_034', 'snap_036', 'snap_038', 'snap_040', 'snap_042', 'snap_044', 'snap_046', 'snap_048', 'snap_050', 'snap_052', 'snap_054', 'snap_056', 'snap_058', 'snap_060', 'snap_062', 'snap_064', 'snap_066', 'snap_068', 'snap_070', 'snap_072', 'snap_074', 'snap_076', 'snap_078', 'snap_080', 'snap_082', 'snap_084', 'snap_086', 'snap_088', 'snap_090']

# %%
import h5py

def print_hdf5_structure(file_path):
    def explore_group(group, level=0):
        # Print the name of the group or dataset
        indent = "  " * level
        for key in group.keys():
            item = group[key]
            if isinstance(item, h5py.Group):  # Check if it's a group
                print(f"{indent}[Group] {key}")
                explore_group(item, level + 1)  # Recursive call
            elif isinstance(item, h5py.Dataset):  # Check if it's a dataset
                print(f"{indent}[Dataset] {key} - Shape: {item.shape}, Dtype: {item.dtype}")
    
    try:
        with h5py.File(file_path, 'r') as hdf_file:
            print(f"Inspecting HDF5 file: {file_path}")
            explore_group(hdf_file)
    except Exception as e:
        print(f"An error occurred while accessing the file: {e}")

# Replace this path with the correct path to your HDF5 file
file_path = "/home/jovyan/Data/Photometry/IllustrisTNG/L25n256/1P/IllustrisTNG_1P_p1_0_photometry.hdf5"
print_hdf5_structure(file_path)
# Out:
# Inspecting HDF5 file: /home/jovyan/Data/Photometry/IllustrisTNG/L25n256/1P/IllustrisTNG_1P_p1_0_photometry.hdf5
# [Group] snap_014
#   [Group] BC03
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#   [Group] BPASS
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (46,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (46,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (46,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (46,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (46,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (46,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (46,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (46,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (46,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (46,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (46,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (46,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (46,), Dtype: float64
#           [Dataset] UV1500 - Shape: (46,), Dtype: float64
#           [Dataset] UV2800 - Shape: (46,), Dtype: float64
#   [Dataset] SubhaloIndex - Shape: (46,), Dtype: int64
# [Group] snap_018
#   [Group] BC03
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#   [Group] BPASS
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (113,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (113,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (113,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (113,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (113,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (113,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (113,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (113,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (113,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (113,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (113,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (113,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (113,), Dtype: float64
#           [Dataset] UV1500 - Shape: (113,), Dtype: float64
#           [Dataset] UV2800 - Shape: (113,), Dtype: float64
#   [Dataset] SubhaloIndex - Shape: (113,), Dtype: int64
# [Group] snap_024
#   [Group] BC03
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (286,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (286,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (286,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (286,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (286,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (286,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (286,), Dtype: float64
#           [Dataset] UV1500 - Shape: (286,), Dtype: float64
#           [Dataset] UV2800 - Shape: (286,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (286,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (286,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (286,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (286,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (286,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (286,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (286,), Dtype: float64
#           [Dataset] UV1500 - Shape: (286,), Dtype: float64
#           [Dataset] UV2800 - Shape: (286,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (286,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (286,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (286,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (286,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (286,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (286,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (286,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (286,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (286,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (286,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (286,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (286,), Dtype: float64
#           [Dataset] UV1500 - Shape: (286,), Dtype: float64
#           [Dataset] UV2800 - Shape: (286,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (286,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (286,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (286,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (286,), Dtype: float64
# ...
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1054,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1054,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1054,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1054,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1054,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1054,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1054,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1054,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1054,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1054,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#   [Group] BPASS
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1054,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1054,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1054,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1054,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1054,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1054,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1054,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1054,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1054,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1054,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1054,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1054,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1054,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1054,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1054,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1054,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1054,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1054,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1054,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1054,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1054,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1054,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1054,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1054,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1054,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1054,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1054,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1054,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1054,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1054,), Dtype: float64
#   [Dataset] SubhaloIndex - Shape: (1054,), Dtype: int64

# %%
import h5py

def print_hdf5_structure(file_path):
    def explore_group(group, level=0):
        # Print the name of the group or dataset
        indent = "  " * level
        for key in group.keys():
            item = group[key]
            if isinstance(item, h5py.Group):  # Check if it's a group
                print(f"{indent}[Group] {key}")
                explore_group(item, level + 1)  # Recursive call
            elif isinstance(item, h5py.Dataset):  # Check if it's a dataset
                print(f"{indent}[Dataset] {key} - Shape: {item.shape}, Dtype: {item.dtype}")
    
    try:
        with h5py.File(file_path, 'r') as hdf_file:
            print(f"Inspecting HDF5 file: {file_path}")
            explore_group(hdf_file)
    except Exception as e:
        print(f"An error occurred while accessing the file: {e}")

# Replace this path with the correct path to your HDF5 file
file_path = "/home/jovyan/Data/Photometry/Swift-EAGLE/L25n256/1P/Swift-EAGLE_1P_p5_2_photometry.hdf5"
print_hdf5_structure(file_path)
# Out:
# Inspecting HDF5 file: /home/jovyan/Data/Photometry/Swift-EAGLE/L25n256/1P/Swift-EAGLE_1P_p5_2_photometry.hdf5
# [Group] snap_086
#   [Group] BC03
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#   [Group] BPASS
#     [Group] photometry
#       [Group] flux
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#       [Group] luminosity
#         [Group] attenuated
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#         [Group] intrinsic
#           [Dataset] GALEX FUV - Shape: (1551,), Dtype: float64
#           [Dataset] GALEX NUV - Shape: (1551,), Dtype: float64
#           [Group] Generic
#             [Dataset] Johnson.B - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.J - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.U - Shape: (1551,), Dtype: float64
#             [Dataset] Johnson.V - Shape: (1551,), Dtype: float64
#           [Group] HST
#             [Dataset] ACS_HRC.F435W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F606W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F775W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F814W - Shape: (1551,), Dtype: float64
#             [Dataset] ACS_HRC.F850LP - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F098M - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F105W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F110W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F125W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F140W - Shape: (1551,), Dtype: float64
#             [Dataset] WFC3_IR.F160W - Shape: (1551,), Dtype: float64
#           [Group] JWST
#             [Dataset] NIRCam.F070W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F090W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F115W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F150W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F200W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F277W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F356W - Shape: (1551,), Dtype: float64
#             [Dataset] NIRCam.F444W - Shape: (1551,), Dtype: float64
#           [Group] SLOAN
#             [Dataset] SDSS.g - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.i - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.r - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.u - Shape: (1551,), Dtype: float64
#             [Dataset] SDSS.z - Shape: (1551,), Dtype: float64
#           [Group] UKIRT
#             [Dataset] UKIDSS.H - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.J - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.K - Shape: (1551,), Dtype: float64
#             [Dataset] UKIDSS.Y - Shape: (1551,), Dtype: float64
#           [Dataset] UV1500 - Shape: (1551,), Dtype: float64
#           [Dataset] UV2800 - Shape: (1551,), Dtype: float64
#   [Dataset] SubhaloIndex - Shape: (1551,), Dtype: int64
