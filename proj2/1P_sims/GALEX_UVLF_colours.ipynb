# %%
import h5py
import numpy as np
from synthesizer.conversions import lnu_to_absolute_mag
import pandas as pd
import unyt
from unyt import erg, Hz, s
import cmasher as cmr
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import os
import sys
sys.path.append("/disk/xray15/aem2/camels/proj2")
from setup_params import get_photometry, get_luminosity_function, get_colour_distribution

# base directories
base_dir = "/disk/xray15/aem2/data/28pams/IllustrisTNG"
input_dir = f"{base_dir}/photometry"

# output directories
lf_output_dir = {
    "GALEX": f"{base_dir}/LFs/GALEX",
    "intrinsic": {
        "UV1500": f"{base_dir}/LFs/intrinsic/UV1500"
    }
}
colour_output_dir = {
    "GALEX": f"{base_dir}/colours/GALEX"
}

# parameters
uvlf_limits = (-24, -16)
uvlf_nbins = 18
colour_limits = (-0.5, 3.5)
nbins_colour = 20

# magnitude limits (DIS) above from https://iopscience.iop.org/article/10.1086/520512/pdf
# NUV=24.4 mag
# FUV=24.8mag
NUV_mag_lim = 24.4
FUV_mag_lim = 24.8

# these are hardcoded in setup_params.py for UVLF calc. so commented out.
#BoxSize = 25.0
#little_h =  0.6711
#Vcom = BoxSize/little_h

# redshift mappings
redshift_values = {
    '044': {'redshift': 2.00, 'label': 'z2.0'},
    '052': {'redshift': 1.48, 'label': 'z1.5'},
    '060': {'redshift': 1.05, 'label': 'z1.0'},
    '086': {'redshift': 0.10, 'label': 'z0.1'}
}

# output directories with redshift subdirectories
# GALEX
for redshift_info in redshift_values.values():
    redshift_dir = os.path.join(lf_output_dir["GALEX"], redshift_info['label'])
    os.makedirs(redshift_dir, exist_ok=True)

# intrinsic wavelengths
for wavelength_dir in lf_output_dir["intrinsic"].values():
    for redshift_info in redshift_values.values():
        redshift_dir = os.path.join(wavelength_dir, redshift_info['label'])
        os.makedirs(redshift_dir, exist_ok=True)

# colours
for dir_path in colour_output_dir.values():
    for redshift_info in redshift_values.values():
        redshift_dir = os.path.join(dir_path, redshift_info['label'])
        os.makedirs(redshift_dir, exist_ok=True)

# telescopes and their parameters
telescopes = {
    "GALEX": {
        "types": ["attenuated", "intrinsic"],  # Fixed syntax and made it a list
        "bands": {
            "FUV": {
                "filter_name": "GALEX FUV",
                "mag_limit": FUV_mag_lim
            },
            "NUV": {
                "filter_name": "GALEX NUV",
                "mag_limit": NUV_mag_lim
            }
        },
        "uvlf_limits": uvlf_limits,
        "uvlf_nbins": uvlf_nbins,
        "colour_pairs": [
            {
                "band1": "FUV",
                "band2": "NUV",
                "limits": colour_limits,
                "nbins": nbins_colour
            }
        ]
    },
    "UV1500": {
        "type": "intrinsic",
        "wavelength": "UV1500",
        "bands": {
            "UV1500": {
                "filter_name": "UV1500",
                "mag_limit": None
            }
        },
        "uvlf_limits": uvlf_limits,
        "uvlf_nbins": uvlf_nbins,
        "colour_pairs": []
    }
}

# %% [markdown]
# ![|](attachment:image.png)

# %%
# test first to check matches Chris.
# vcom and h doesnt need defining as hard coded in uvlf calc in setup_params.py

# specify the path to the photometry file for testing
photo_file = "/disk/xray15/aem2/data/28pams/IllTNG/photometry/IllustrisTNG_1P_p1_0_photometry.hdf5"

# load photometry data with GALEX filters
# see setup_params.py - this returns the AB magnitude in erg/s/Hz
filters = ["GALEX FUV", "GALEX NUV"]

photo_in = get_photometry(
    sim_name="1P_p1_0",
    spec_type="intrinsic",
    snap="086",
    sps="BC03",
    model="IllustrisTNG",
    filters=filters,
    photo_dir=input_dir
    )

print(photo_in.keys())
# calculate UV luminosity function (UVLF) for FUV and NUV

phi_FUV_in, phi_sigma_FUV_in, hist_FUV_in, bin_lims_FUV_in = get_luminosity_function(
    photo_in, "GALEX FUV", *uvlf_limits, n_bins=uvlf_nbins
)
phi_NUV_in, phi_sigma_NUV_in, hist_NUV_in, bin_lims_NUV_in = get_luminosity_function(
    photo_in, "GALEX NUV", *uvlf_limits, n_bins=uvlf_nbins
)

photo_att = get_photometry(
    sim_name="1P_p1_0",
    spec_type="attenuated",
    snap="044",
    sps="BC03",
    model="IllustrisTNG",
    filters=filters,
    photo_dir=input_dir
    )

# calculate UV luminosity function (UVLF) for FUV and NUV
phi_FUV_att, phi_sigma_FUV_att, hist_FUV_att, bin_lims_FUV_att = get_luminosity_function(
    photo_att, "GALEX FUV", *uvlf_limits, n_bins=uvlf_nbins
)
phi_NUV_att, phi_sigma_NUV_att, hist_NUV_att, bin_lims_NUV_att = get_luminosity_function(
    photo_att, "GALEX NUV", *uvlf_limits, n_bins=uvlf_nbins
)
# Out:
# dict_keys(['GALEX FUV', 'GALEX NUV'])

# %%
print(photo_in['GALEX FUV'])
# Out:
# [-19.81150562 -17.07353905 -14.46740957 ... -15.64613201  -8.70392497
#   -8.97679498]

# %%
photo_in['GALEX FUV'].min()
# Out:
# -21.96054576865304

# %%
print(photo_in['GALEX NUV'])
# Out:
# [-20.19437517 -17.59589366 -15.80971859 ... -15.64991915 -11.20159378
#  -11.39035799]

# %%
# plot UV luminosity function (UVLF) for GALEX FUV and NUV
fig, ax = plt.subplots(1, figsize=(8, 6))
ax.grid(True, which='both', linestyle='--', alpha=0.6)

# INTRINSIC
# plot FUV UVLF
ax.plot(bin_lims_FUV_in[:-1], phi_FUV_in, label="FUV (Intrinsic)", color="blue", ls='--', zorder=2)
ax.fill_between(bin_lims_FUV_in[:-1], 
                phi_FUV_in - phi_sigma_FUV_in, 
                phi_FUV_in + phi_sigma_FUV_in, 
                color="blue", alpha=0.5, zorder=1)

# plot NUV UVLF
ax.plot(bin_lims_NUV_in[:-1], phi_NUV_in, label="NUV (Intrinsic)", color="orange", ls='--', zorder=2)
ax.fill_between(bin_lims_NUV_in[:-1], 
                phi_NUV_in - phi_sigma_NUV_in, 
                phi_NUV_in + phi_sigma_NUV_in, 
                color="orange", alpha=0.5, zorder=1)

# ATTENUATED
# plot FUV UVLF
ax.plot(bin_lims_FUV_att[:-1], phi_FUV_att, label="FUV (Attenuated)", color="blue", ls='-', zorder=2)
ax.fill_between(bin_lims_FUV_att[:-1], 
                phi_FUV_att - phi_sigma_FUV_att, 
                phi_FUV_att + phi_sigma_FUV_att, 
                color="blue", alpha=0.3, zorder=1)

# plot NUV UVLF
ax.plot(bin_lims_NUV_att[:-1], phi_NUV_att, label="NUV (Attenuated)", color="orange", ls='-', zorder=2)
ax.fill_between(bin_lims_NUV_att[:-1], 
                phi_NUV_att - phi_sigma_NUV_att, 
                phi_NUV_att + phi_sigma_NUV_att, 
                color="orange", alpha=0.3, zorder=1)

# set x and y lims
ax.set_xlim(-24,-16)
ax.set_ylim(-5.5,-2)

# add labels and title
ax.set_xlabel('Absolute Magnitude (AB)')
ax.set_ylabel('Number Density (Mpc$^{-3}$ mag$^{-1}$)')
ax.legend(loc='upper left', fontsize=8)
ax.set_title("UV Luminosity Function GALEX (FUV and NUV)")

plt.tight_layout()
plt.show()

# %%
fuv_mask = photo_in["GALEX FUV"] < FUV_mag_lim # Only include galaxies brighter than FUV=25
nuv_mask = photo_in["GALEX NUV"] < NUV_mag_lim # Only include galaxies brighter than NUV=25.3
combined_mask = fuv_mask & nuv_mask

# %%
# show how many galaxies make the cut
print(f"\nTotal galaxies: {len(photo_in['GALEX FUV'])}")
print(f"Galaxies after magnitude cuts: {np.sum(combined_mask)}")
# Out:
# Total galaxies: 1066
# Galaxies after magnitude cuts: 1066

# %%
# check the full color range
test_color = photo_in["GALEX FUV"] - photo_in["GALEX NUV"]
print("Full color range in data:")
print(f"Min: {np.min(test_color)}")
print(f"Max: {np.max(test_color)}")
# Out:
# Full color range in data:
# Min: -0.37612790767960647
# Max: 3.3271137306041894

# %%
#get colour dist for fuv and nuv
 
colour_dist_in, bin_lims_colour_in = get_colour_distribution(
    photo=photo_in,
    filtA="GALEX FUV",
    filtB="GALEX NUV",
    lo_lim=-0.5,
    hi_lim=3.5,
    n_bins=20,
    mask=combined_mask  # apply our magnitude limit mask
)

# %%
# get colors for galaxies within magnitude limits
colors = photo_in["GALEX FUV"][combined_mask] - photo_in["GALEX NUV"][combined_mask]

fig, ax = plt.subplots(1, figsize=(8, 6))

# hist plot
ax.hist(colors, bins=30, density=True, alpha=0.7, color='royalblue', 
        edgecolor='black', linewidth=1, label='FUV - NUV')

ax.set_xlabel('FUV - NUV [mag]', fontsize=12)
ax.set_ylabel('Normalized Count', fontsize=12)
ax.set_title('GALEX Color Distribution\n(Magnitude limited: FUV < 25, NUV < 25.3)', 
             fontsize=12, pad=10)

ax.grid(True, linestyle='--', alpha=0.3)
ax.set_xlim(-0.5, 3.5)
ax.legend()

plt.tight_layout()
plt.show()

print(f"Number of galaxies after magnitude cuts: {len(colors)}")
print(f"Mean color: {np.mean(colors):.2f}")
print(f"Median color: {np.median(colors):.2f}")
# Out:
# Number of galaxies after magnitude cuts: 1066
# Mean color: 1.27
# Median color: 1.20

# %%
#  test file details
sim_name = "1P_p1_0"
snap = "086"  # z=0.1
redshift = 0.1

# photometry using chris function
# note this gets photometry and puts into Absolute AB magnitudes already.
photo_in = get_photometry(
    sim_name=sim_name,
    spec_type="intrinsic",
    snap=snap,
    sps="BC03",
    model="IllustrisTNG",
    filters=["GALEX FUV", "GALEX NUV"],
    photo_dir=input_dir
)

phi_FUV, phi_sigma_FUV, hist_FUV, bin_limits_FUV = get_luminosity_function(
    photo_in, 
    "GALEX FUV", 
    *uvlf_limits, 
    n_bins=uvlf_nbins
)
phi_NUV, phi_sigma_NUV, hist_NUV, bin_limits_NUV = get_luminosity_function(
    photo_in, "GALEX NUV", *uvlf_limits, n_bins=uvlf_nbins
)

# %%
photo_in
# Out:
# {'GALEX FUV': array([-19.81150562, -17.07353905, -14.46740957, ..., -15.64613201,
#          -8.70392497,  -8.97679498]),
#  'GALEX NUV': array([-20.19437517, -17.59589366, -15.80971859, ..., -15.64991915,
#         -11.20159378, -11.39035799])}

# %%
plt.figure(figsize=(10, 6))
# fuv
plt.errorbar(bin_limits_FUV[:-1], phi_FUV, yerr=phi_sigma_FUV, 
            fmt='o', color='blue', label='FUV', capsize=5)
# nuv
plt.errorbar(bin_limits_NUV[:-1], phi_NUV, yerr=phi_sigma_NUV, 
            fmt='o', color='orange', label='NUV', capsize=5)

plt.xlabel('Absolute Magnitude (AB)')
plt.ylabel('Number Density (Mpc$^{-3}$ mag$^{-1}$)')
#plt.yscale('log')
plt.title(f'GALEX UV Luminosity Function (z = {redshift})')
plt.legend()
plt.grid(True, which='both', linestyle='--', alpha=0.6)
plt.xlim(-22,-16)
plt.ylim(-5, -2.5)

plt.tight_layout()
plt.show()

print(f"\nNumber of galaxies:")
print(f"FUV: {len(photo_in['GALEX FUV'])}")
print(f"NUV: {len(photo_in['GALEX NUV'])}")
print(f"\nMagnitude ranges:")
print(f"FUV: {photo_in['GALEX FUV'].min():.2f} to {photo_in['GALEX FUV'].max():.2f}")
print(f"NUV: {photo_in['GALEX NUV'].min():.2f} to {photo_in['GALEX NUV'].max():.2f}")
# Out:
# Number of galaxies:
# FUV: 1066
# NUV: 1066
#
# Magnitude ranges:
# FUV: -21.96 to -6.94
# NUV: -21.84 to -9.18

# %% [markdown]
# ### this is the same plot as Chris paper, as a sanity check, everything looks solid and agrees:
# ### just reffering to the upper left plot (omega 0 fiducial) which is attenuated galex fuv at 0.1, same as above
#
# ![image.png](attachment:image.png)

# %%
# but we actually want UVLF for intrinsic with GALEX and then the colours.

# %%
# First check what we're working with
print("Data type and units check:")
print("FUV type:", type(photo_in['GALEX FUV']))
print("FUV example value:", photo_in['GALEX FUV'][0])

# These are already in AB magnitudes (from lnu_to_absolute_mag in get_photometry)
# Now let's create magnitude limits mask for GALEX
fuv_mask = photo_in["GALEX FUV"] < 25.5  # FUV magnitude limit
nuv_mask = photo_in["GALEX NUV"] < 25.5  # NUV magnitude limit
combined_mask = fuv_mask & nuv_mask

# Calculate color distribution using the function from setup_params
colour_dist_in, bin_lims_colour_in = get_colour_distribution(
    photo=photo_in,
    filtA="GALEX FUV",
    filtB="GALEX NUV",
    lo_lim=-0.5,  # Based on typical FUV-NUV color ranges
    hi_lim=3.5,
    n_bins=20,
    mask=combined_mask
)

colour_dist_in
# Out:
# Data type and units check:
# FUV type: <class 'numpy.ndarray'>
# FUV example value: -19.811505621948424
# array([0.02227955, 0.27626642, 0.494606  , 0.65056285, 0.40103189,
#        0.27181051, 0.15150094, 0.10248593, 0.15150094, 0.16486867,
#        0.15150094, 0.19160413, 0.47232645, 0.42776735, 0.34756098,
#        0.27626642, 0.12476548, 0.06683865, 0.00445591])

# %%
# Create histogram plot
fig, ax = plt.subplots(1, figsize=(8, 6))

# Calculate bin centers for plotting
mid_bins = 0.5 * (bin_lims_colour_in[:-1] + bin_lims_colour_in[1:])

# Plot color distribution
ax.hist(photo_in["GALEX FUV"][combined_mask] - photo_in["GALEX NUV"][combined_mask], 
        bins=bin_lims_colour_in, density=True, alpha=0.7, color='royalblue',
        edgecolor='black', linewidth=1)

# Customize plot
ax.set_xlabel('FUV - NUV [mag]', fontsize=12)
ax.set_ylabel('Normalized Count', fontsize=12)
ax.set_title('GALEX Color Distribution\n(Magnitude limited: FUV < 25, NUV < 25.3)', 
             fontsize=12, pad=10)
ax.grid(True, linestyle='--', alpha=0.3)

# Print some statistics
colors = photo_in["GALEX FUV"][combined_mask] - photo_in["GALEX NUV"][combined_mask]
print("\nColor statistics after magnitude cuts:")
print(f"Number of galaxies: {len(colors)}")
print(f"Mean FUV-NUV color: {np.mean(colors):.2f}")
print(f"Median FUV-NUV color: {np.median(colors):.2f}")
print(f"Color range: {np.min(colors):.2f} to {np.max(colors):.2f}")

plt.tight_layout()
plt.show()
# Out:
# Color statistics after magnitude cuts:
# Number of galaxies: 1066
# Mean FUV-NUV color: 1.27
# Median FUV-NUV color: 1.20
# Color range: -0.38 to 3.33

# %%
def process_single_snapshot(sim_name, snap, telescope, telescope_params, spec_type=None):
   """Process a single snapshot for both UVLF and colours"""
   
   if telescope == "UV1500":
       # Special handling for UV1500
       file_path = os.path.join(input_dir, f"IllustrisTNG_{sim_name}_photometry.hdf5")
       with h5py.File(file_path, 'r') as hdf:
           lum_UV1500 = hdf[f'/snap_{snap}/BC03/photometry/luminosity/intrinsic/UV1500'][:]
           lum_UV1500_unyt = lum_UV1500 * erg / (Hz * s)
           abs_mags = lnu_to_absolute_mag(lum_UV1500_unyt)
           
           # Use get_luminosity_function from setup_params
           phi, phi_sigma, hist, bin_lims = get_luminosity_function(
               {"UV1500": abs_mags},  # Create dict to match photo format
               "UV1500",
               *telescope_params["uvlf_limits"],
               n_bins=telescope_params["uvlf_nbins"]
           )
           
           return {
               'uvlf': {
                   'UV1500': (phi, phi_sigma, hist, bin_lims)
               },
               'colours': {}
           }
   
   else:
       # Get list of all filters needed for this telescope
       filters = [band_info["filter_name"] for band_info in telescope_params["bands"].values()]
       
       # Get photometry with specified spec_type
       photo = get_photometry(
           sim_name=sim_name,
           spec_type=spec_type,  # Now using the passed spec_type
           snap=snap,
           sps="BC03",
           model="IllustrisTNG",
           filters=filters,
           photo_dir=input_dir
       )
       
       # Create masks for each band
       masks = {
           band: photo[band_info["filter_name"]] < band_info["mag_limit"]
           for band, band_info in telescope_params["bands"].items()
       }
       
       # Process UVLFs for each band using get_luminosity_function from setup_params
       uvlf_results = {}
       for band, band_info in telescope_params["bands"].items():
           phi, phi_sigma, hist, bin_lims = get_luminosity_function(
               photo, 
               band_info["filter_name"], 
               *telescope_params["uvlf_limits"],
               n_bins=telescope_params["uvlf_nbins"]
           )
           uvlf_results[band] = (phi, phi_sigma, hist, bin_lims)
       
       # Process colours for each colour pair
       colour_results = {}
       for colour_pair in telescope_params["colour_pairs"]:
           band1, band2 = colour_pair["band1"], colour_pair["band2"]
           combined_mask = masks[band1] & masks[band2]
           
           colour_dist, bin_lims_colour = get_colour_distribution(
               photo,
               telescope_params["bands"][band1]["filter_name"],
               telescope_params["bands"][band2]["filter_name"],
               *colour_pair["limits"],
               n_bins=colour_pair["nbins"],
               mask=combined_mask
           )
           colour_results[f"{band1}-{band2}"] = (colour_dist, bin_lims_colour)
       
       return {
           'uvlf': uvlf_results,
           'colours': colour_results
       }

# Process each file in the directory
for filename in os.listdir(input_dir):
   if filename.endswith("_photometry.hdf5"):
       sim_name = filename.replace('IllustrisTNG_', '').replace('_photometry.hdf5', '')
       print(f"Processing {sim_name}")
       
       for telescope, telescope_params in telescopes.items():
           print(f"Processing telescope: {telescope}")
           
           # Handle different spec_types for GALEX
           if telescope == "GALEX":
               spec_types = telescope_params["types"]
           else:
               spec_types = [telescope_params["type"]]
               
           for spec_type in spec_types:
               for snap in redshift_values.keys():
                   try:
                       # Process the snapshot with spec_type
                       results = process_single_snapshot(sim_name, snap, telescope, 
                                                      telescope_params, spec_type)
                       
                       if telescope == "UV1500":
                           # Save UV1500 results
                           for band in results['uvlf']:
                               phi, phi_sigma, hist, bin_lims = results['uvlf'][band]
                               bin_centers = 0.5 * (bin_lims[1:] + bin_lims[:-1])
                               
                               uvlf_df = pd.DataFrame({
                                   'magnitude': bin_centers,
                                   'phi': phi,
                                   'phi_sigma': phi_sigma,
                                   'hist': hist
                               })
                               
                               uvlf_filename = f"UVLF_{sim_name}_UV1500_{redshift_values[snap]['label']}.txt"
                               redshift_dir = os.path.join(lf_output_dir["intrinsic"]["UV1500"], 
                                                         redshift_values[snap]['label'])
                               uvlf_df.to_csv(
                                   os.path.join(redshift_dir, uvlf_filename), 
                                   index=False, sep='\t'
                               )
                       
                       else:
                           # Save GALEX UVLF results with spec_type in filename
                           for band in telescope_params["bands"]:
                               phi, phi_sigma, hist, bin_lims = results['uvlf'][band]
                               bin_centers = 0.5 * (bin_lims[1:] + bin_lims[:-1])
                               
                               uvlf_df = pd.DataFrame({
                                   'magnitude': bin_centers,
                                   'phi': phi,
                                   'phi_sigma': phi_sigma,
                                   'hist': hist
                               })
                               
                               uvlf_filename = f"UVLF_{sim_name}_{band}_{redshift_values[snap]['label']}_{spec_type}.txt"
                               redshift_dir = os.path.join(lf_output_dir["GALEX"], 
                                                         redshift_values[snap]['label'])
                               uvlf_df.to_csv(
                                   os.path.join(redshift_dir, uvlf_filename), 
                                   index=False, sep='\t'
                               )
                           
                           # Save GALEX colour results with spec_type in filename
                           for colour_pair in telescope_params["colour_pairs"]:
                               colour_name = f"{colour_pair['band1']}-{colour_pair['band2']}"
                               colour_dist, bin_lims_colour = results['colours'][colour_name]
                               bin_centers = 0.5 * (bin_lims_colour[1:] + bin_lims_colour[:-1])
                               
                               colour_df = pd.DataFrame({
                                   'colour': bin_centers,
                                   'distribution': colour_dist
                               })
                               
                               colour_filename = f"Colour_{sim_name}_{colour_name}_{redshift_values[snap]['label']}_{spec_type}.txt"
                               redshift_dir = os.path.join(colour_output_dir["GALEX"], 
                                                         redshift_values[snap]['label'])
                               colour_df.to_csv(
                                   os.path.join(redshift_dir, colour_filename), 
                                   index=False, sep='\t'
                               )
                       
                       print(f"Processed {sim_name} {telescope} {spec_type} {redshift_values[snap]['label']}")
                       
                   except Exception as e:
                       print(f"Error processing {sim_name} {telescope} {spec_type} {redshift_values[snap]['label']}: {str(e)}")
                       continue

print("Processing complete!")
# Out:
# Processing 1P_p7_2
# Processing telescope: GALEX
# Processed 1P_p7_2 GALEX attenuated z2.0
# Processed 1P_p7_2 GALEX attenuated z1.5
# Processed 1P_p7_2 GALEX attenuated z1.0
# Processed 1P_p7_2 GALEX attenuated z0.1
# Processed 1P_p7_2 GALEX intrinsic z2.0
# Processed 1P_p7_2 GALEX intrinsic z1.5
# Processed 1P_p7_2 GALEX intrinsic z1.0
# Processed 1P_p7_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p7_2 UV1500 intrinsic z2.0
# Processed 1P_p7_2 UV1500 intrinsic z1.5
# Processed 1P_p7_2 UV1500 intrinsic z1.0
# Processed 1P_p7_2 UV1500 intrinsic z0.1
# Processing 1P_p9_n1
# Processing telescope: GALEX
# Processed 1P_p9_n1 GALEX attenuated z2.0
# Processed 1P_p9_n1 GALEX attenuated z1.5
# Processed 1P_p9_n1 GALEX attenuated z1.0
# Processed 1P_p9_n1 GALEX attenuated z0.1
# Processed 1P_p9_n1 GALEX intrinsic z2.0
# Processed 1P_p9_n1 GALEX intrinsic z1.5
# Processed 1P_p9_n1 GALEX intrinsic z1.0
# Processed 1P_p9_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p9_n1 UV1500 intrinsic z2.0
# Processed 1P_p9_n1 UV1500 intrinsic z1.5
# Processed 1P_p9_n1 UV1500 intrinsic z1.0
# Processed 1P_p9_n1 UV1500 intrinsic z0.1
# Processing 1P_p14_n2
# Processing telescope: GALEX
# Processed 1P_p14_n2 GALEX attenuated z2.0
# Processed 1P_p14_n2 GALEX attenuated z1.5
# Processed 1P_p14_n2 GALEX attenuated z1.0
# Processed 1P_p14_n2 GALEX attenuated z0.1
# Processed 1P_p14_n2 GALEX intrinsic z2.0
# Processed 1P_p14_n2 GALEX intrinsic z1.5
# Processed 1P_p14_n2 GALEX intrinsic z1.0
# Processed 1P_p14_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p14_n2 UV1500 intrinsic z2.0
# Processed 1P_p14_n2 UV1500 intrinsic z1.5
# Processed 1P_p14_n2 UV1500 intrinsic z1.0
# Processed 1P_p14_n2 UV1500 intrinsic z0.1
# Processing 1P_p23_n1
# Processing telescope: GALEX
# Processed 1P_p23_n1 GALEX attenuated z2.0
# Processed 1P_p23_n1 GALEX attenuated z1.5
# Processed 1P_p23_n1 GALEX attenuated z1.0
# Processed 1P_p23_n1 GALEX attenuated z0.1
# Processed 1P_p23_n1 GALEX intrinsic z2.0
# Processed 1P_p23_n1 GALEX intrinsic z1.5
# Processed 1P_p23_n1 GALEX intrinsic z1.0
# Processed 1P_p23_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p23_n1 UV1500 intrinsic z2.0
# Processed 1P_p23_n1 UV1500 intrinsic z1.5
# Processed 1P_p23_n1 UV1500 intrinsic z1.0
# Processed 1P_p23_n1 UV1500 intrinsic z0.1
# Processing 1P_p24_1
# Processing telescope: GALEX
# Processed 1P_p24_1 GALEX attenuated z2.0
# Processed 1P_p24_1 GALEX attenuated z1.5
# Processed 1P_p24_1 GALEX attenuated z1.0
# Processed 1P_p24_1 GALEX attenuated z0.1
# Processed 1P_p24_1 GALEX intrinsic z2.0
# Processed 1P_p24_1 GALEX intrinsic z1.5
# Processed 1P_p24_1 GALEX intrinsic z1.0
# Processed 1P_p24_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p24_1 UV1500 intrinsic z2.0
# Processed 1P_p24_1 UV1500 intrinsic z1.5
# Processed 1P_p24_1 UV1500 intrinsic z1.0
# Processed 1P_p24_1 UV1500 intrinsic z0.1
# Processing 1P_p5_n1
# Processing telescope: GALEX
# Processed 1P_p5_n1 GALEX attenuated z2.0
# Processed 1P_p5_n1 GALEX attenuated z1.5
# Processed 1P_p5_n1 GALEX attenuated z1.0
# Processed 1P_p5_n1 GALEX attenuated z0.1
# Processed 1P_p5_n1 GALEX intrinsic z2.0
# Processed 1P_p5_n1 GALEX intrinsic z1.5
# Processed 1P_p5_n1 GALEX intrinsic z1.0
# Processed 1P_p5_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p5_n1 UV1500 intrinsic z2.0
# Processed 1P_p5_n1 UV1500 intrinsic z1.5
# Processed 1P_p5_n1 UV1500 intrinsic z1.0
# Processed 1P_p5_n1 UV1500 intrinsic z0.1
# Processing 1P_p11_n1
# Processing telescope: GALEX
# Processed 1P_p11_n1 GALEX attenuated z2.0
# Processed 1P_p11_n1 GALEX attenuated z1.5
# Processed 1P_p11_n1 GALEX attenuated z1.0
# Processed 1P_p11_n1 GALEX attenuated z0.1
# Processed 1P_p11_n1 GALEX intrinsic z2.0
# Processed 1P_p11_n1 GALEX intrinsic z1.5
# Processed 1P_p11_n1 GALEX intrinsic z1.0
# Processed 1P_p11_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p11_n1 UV1500 intrinsic z2.0
# Processed 1P_p11_n1 UV1500 intrinsic z1.5
# Processed 1P_p11_n1 UV1500 intrinsic z1.0
# Processed 1P_p11_n1 UV1500 intrinsic z0.1
# Processing 1P_p23_2
# Processing telescope: GALEX
# Processed 1P_p23_2 GALEX attenuated z2.0
# Processed 1P_p23_2 GALEX attenuated z1.5
# Processed 1P_p23_2 GALEX attenuated z1.0
# Processed 1P_p23_2 GALEX attenuated z0.1
# Processed 1P_p23_2 GALEX intrinsic z2.0
# Processed 1P_p23_2 GALEX intrinsic z1.5
# Processed 1P_p23_2 GALEX intrinsic z1.0
# Processed 1P_p23_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p23_2 UV1500 intrinsic z2.0
# Processed 1P_p23_2 UV1500 intrinsic z1.5
# Processed 1P_p23_2 UV1500 intrinsic z1.0
# Processed 1P_p23_2 UV1500 intrinsic z0.1
# Processing 1P_p18_n2
# Processing telescope: GALEX
# Processed 1P_p18_n2 GALEX attenuated z2.0
# Processed 1P_p18_n2 GALEX attenuated z1.5
# Processed 1P_p18_n2 GALEX attenuated z1.0
# Processed 1P_p18_n2 GALEX attenuated z0.1
# Processed 1P_p18_n2 GALEX intrinsic z2.0
# Processed 1P_p18_n2 GALEX intrinsic z1.5
# Processed 1P_p18_n2 GALEX intrinsic z1.0
# Processed 1P_p18_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p18_n2 UV1500 intrinsic z2.0
# Processed 1P_p18_n2 UV1500 intrinsic z1.5
# Processed 1P_p18_n2 UV1500 intrinsic z1.0
# Processed 1P_p18_n2 UV1500 intrinsic z0.1
# Processing 1P_p26_n2
# Processing telescope: GALEX
# Processed 1P_p26_n2 GALEX attenuated z2.0
# Processed 1P_p26_n2 GALEX attenuated z1.5
# Processed 1P_p26_n2 GALEX attenuated z1.0
# Processed 1P_p26_n2 GALEX attenuated z0.1
# Processed 1P_p26_n2 GALEX intrinsic z2.0
# Processed 1P_p26_n2 GALEX intrinsic z1.5
# Processed 1P_p26_n2 GALEX intrinsic z1.0
# Processed 1P_p26_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p26_n2 UV1500 intrinsic z2.0
# Processed 1P_p26_n2 UV1500 intrinsic z1.5
# Processed 1P_p26_n2 UV1500 intrinsic z1.0
# Processed 1P_p26_n2 UV1500 intrinsic z0.1
# Processing 1P_p17_2
# Processing telescope: GALEX
# Processed 1P_p17_2 GALEX attenuated z2.0
# Processed 1P_p17_2 GALEX attenuated z1.5
# Processed 1P_p17_2 GALEX attenuated z1.0
# Processed 1P_p17_2 GALEX attenuated z0.1
# Processed 1P_p17_2 GALEX intrinsic z2.0
# Processed 1P_p17_2 GALEX intrinsic z1.5
# Processed 1P_p17_2 GALEX intrinsic z1.0
# Processed 1P_p17_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p17_2 UV1500 intrinsic z2.0
# Processed 1P_p17_2 UV1500 intrinsic z1.5
# Processed 1P_p17_2 UV1500 intrinsic z1.0
# Processed 1P_p17_2 UV1500 intrinsic z0.1
# Processing 1P_p28_2
# Processing telescope: GALEX
# Processed 1P_p28_2 GALEX attenuated z2.0
# Processed 1P_p28_2 GALEX attenuated z1.5
# Processed 1P_p28_2 GALEX attenuated z1.0
# Processed 1P_p28_2 GALEX attenuated z0.1
# Processed 1P_p28_2 GALEX intrinsic z2.0
# Processed 1P_p28_2 GALEX intrinsic z1.5
# Processed 1P_p28_2 GALEX intrinsic z1.0
# Processed 1P_p28_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p28_2 UV1500 intrinsic z2.0
# Processed 1P_p28_2 UV1500 intrinsic z1.5
# Processed 1P_p28_2 UV1500 intrinsic z1.0
# Processed 1P_p28_2 UV1500 intrinsic z0.1
# Processing 1P_p10_1
# Processing telescope: GALEX
# Processed 1P_p10_1 GALEX attenuated z2.0
# Processed 1P_p10_1 GALEX attenuated z1.5
# Processed 1P_p10_1 GALEX attenuated z1.0
# Processed 1P_p10_1 GALEX attenuated z0.1
# Processed 1P_p10_1 GALEX intrinsic z2.0
# Processed 1P_p10_1 GALEX intrinsic z1.5
# Processed 1P_p10_1 GALEX intrinsic z1.0
# Processed 1P_p10_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p10_1 UV1500 intrinsic z2.0
# Processed 1P_p10_1 UV1500 intrinsic z1.5
# Processed 1P_p10_1 UV1500 intrinsic z1.0
# Processed 1P_p10_1 UV1500 intrinsic z0.1
# Processing 1P_p13_n2
# Processing telescope: GALEX
# Processed 1P_p13_n2 GALEX attenuated z2.0
# Processed 1P_p13_n2 GALEX attenuated z1.5
# Processed 1P_p13_n2 GALEX attenuated z1.0
# Processed 1P_p13_n2 GALEX attenuated z0.1
# Processed 1P_p13_n2 GALEX intrinsic z2.0
# Processed 1P_p13_n2 GALEX intrinsic z1.5
# Processed 1P_p13_n2 GALEX intrinsic z1.0
# Processed 1P_p13_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p13_n2 UV1500 intrinsic z2.0
# Processed 1P_p13_n2 UV1500 intrinsic z1.5
# Processed 1P_p13_n2 UV1500 intrinsic z1.0
# Processed 1P_p13_n2 UV1500 intrinsic z0.1
# Processing 1P_p16_1
# Processing telescope: GALEX
# Processed 1P_p16_1 GALEX attenuated z2.0
# Processed 1P_p16_1 GALEX attenuated z1.5
# Processed 1P_p16_1 GALEX attenuated z1.0
# Processed 1P_p16_1 GALEX attenuated z0.1
# Processed 1P_p16_1 GALEX intrinsic z2.0
# Processed 1P_p16_1 GALEX intrinsic z1.5
# Processed 1P_p16_1 GALEX intrinsic z1.0
# Processed 1P_p16_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p16_1 UV1500 intrinsic z2.0
# Processed 1P_p16_1 UV1500 intrinsic z1.5
# Processed 1P_p16_1 UV1500 intrinsic z1.0
# Processed 1P_p16_1 UV1500 intrinsic z0.1
# Processing 1P_p24_n1
# Processing telescope: GALEX
# Processed 1P_p24_n1 GALEX attenuated z2.0
# Processed 1P_p24_n1 GALEX attenuated z1.5
# Processed 1P_p24_n1 GALEX attenuated z1.0
# Processed 1P_p24_n1 GALEX attenuated z0.1
# Processed 1P_p24_n1 GALEX intrinsic z2.0
# Processed 1P_p24_n1 GALEX intrinsic z1.5
# Processed 1P_p24_n1 GALEX intrinsic z1.0
# Processed 1P_p24_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p24_n1 UV1500 intrinsic z2.0
# Processed 1P_p24_n1 UV1500 intrinsic z1.5
# Processed 1P_p24_n1 UV1500 intrinsic z1.0
# Processed 1P_p24_n1 UV1500 intrinsic z0.1
# Processing 1P_p11_2
# Processing telescope: GALEX
# Processed 1P_p11_2 GALEX attenuated z2.0
# Processed 1P_p11_2 GALEX attenuated z1.5
# Processed 1P_p11_2 GALEX attenuated z1.0
# Processed 1P_p11_2 GALEX attenuated z0.1
# Processed 1P_p11_2 GALEX intrinsic z2.0
# Processed 1P_p11_2 GALEX intrinsic z1.5
# Processed 1P_p11_2 GALEX intrinsic z1.0
# Processed 1P_p11_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p11_2 UV1500 intrinsic z2.0
# Processed 1P_p11_2 UV1500 intrinsic z1.5
# Processed 1P_p11_2 UV1500 intrinsic z1.0
# Processed 1P_p11_2 UV1500 intrinsic z0.1
# Processing 1P_p7_n2
# Processing telescope: GALEX
# Processed 1P_p7_n2 GALEX attenuated z2.0
# Processed 1P_p7_n2 GALEX attenuated z1.5
# Processed 1P_p7_n2 GALEX attenuated z1.0
# Processed 1P_p7_n2 GALEX attenuated z0.1
# Processed 1P_p7_n2 GALEX intrinsic z2.0
# Processed 1P_p7_n2 GALEX intrinsic z1.5
# Processed 1P_p7_n2 GALEX intrinsic z1.0
# Processed 1P_p7_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p7_n2 UV1500 intrinsic z2.0
# Processed 1P_p7_n2 UV1500 intrinsic z1.5
# Processed 1P_p7_n2 UV1500 intrinsic z1.0
# Processed 1P_p7_n2 UV1500 intrinsic z0.1
# Processing 1P_p25_2
# Processing telescope: GALEX
# Processed 1P_p25_2 GALEX attenuated z2.0
# Processed 1P_p25_2 GALEX attenuated z1.5
# Processed 1P_p25_2 GALEX attenuated z1.0
# Processed 1P_p25_2 GALEX attenuated z0.1
# Processed 1P_p25_2 GALEX intrinsic z2.0
# Processed 1P_p25_2 GALEX intrinsic z1.5
# Processed 1P_p25_2 GALEX intrinsic z1.0
# Processed 1P_p25_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p25_2 UV1500 intrinsic z2.0
# Processed 1P_p25_2 UV1500 intrinsic z1.5
# Processed 1P_p25_2 UV1500 intrinsic z1.0
# Processed 1P_p25_2 UV1500 intrinsic z0.1
# Processing 1P_p22_1
# Processing telescope: GALEX
# Processed 1P_p22_1 GALEX attenuated z2.0
# Processed 1P_p22_1 GALEX attenuated z1.5
# Processed 1P_p22_1 GALEX attenuated z1.0
# Processed 1P_p22_1 GALEX attenuated z0.1
# Processed 1P_p22_1 GALEX intrinsic z2.0
# Processed 1P_p22_1 GALEX intrinsic z1.5
# Processed 1P_p22_1 GALEX intrinsic z1.0
# Processed 1P_p22_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p22_1 UV1500 intrinsic z2.0
# Processed 1P_p22_1 UV1500 intrinsic z1.5
# Processed 1P_p22_1 UV1500 intrinsic z1.0
# Processed 1P_p22_1 UV1500 intrinsic z0.1
# Processing 1P_p6_1
# Processing telescope: GALEX
# Processed 1P_p6_1 GALEX attenuated z2.0
# Processed 1P_p6_1 GALEX attenuated z1.5
# Processed 1P_p6_1 GALEX attenuated z1.0
# Processed 1P_p6_1 GALEX attenuated z0.1
# Processed 1P_p6_1 GALEX intrinsic z2.0
# Processed 1P_p6_1 GALEX intrinsic z1.5
# Processed 1P_p6_1 GALEX intrinsic z1.0
# Processed 1P_p6_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p6_1 UV1500 intrinsic z2.0
# Processed 1P_p6_1 UV1500 intrinsic z1.5
# Processed 1P_p6_1 UV1500 intrinsic z1.0
# Processed 1P_p6_1 UV1500 intrinsic z0.1
# Processing 1P_p1_2
# Processing telescope: GALEX
# Processed 1P_p1_2 GALEX attenuated z2.0
# Processed 1P_p1_2 GALEX attenuated z1.5
# Processed 1P_p1_2 GALEX attenuated z1.0
# Processed 1P_p1_2 GALEX attenuated z0.1
# Processed 1P_p1_2 GALEX intrinsic z2.0
# Processed 1P_p1_2 GALEX intrinsic z1.5
# Processed 1P_p1_2 GALEX intrinsic z1.0
# Processed 1P_p1_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p1_2 UV1500 intrinsic z2.0
# Processed 1P_p1_2 UV1500 intrinsic z1.5
# Processed 1P_p1_2 UV1500 intrinsic z1.0
# Processed 1P_p1_2 UV1500 intrinsic z0.1
# Processing 1P_p28_n1
# Processing telescope: GALEX
# Processed 1P_p28_n1 GALEX attenuated z2.0
# Processed 1P_p28_n1 GALEX attenuated z1.5
# Processed 1P_p28_n1 GALEX attenuated z1.0
# Processed 1P_p28_n1 GALEX attenuated z0.1
# Processed 1P_p28_n1 GALEX intrinsic z2.0
# Processed 1P_p28_n1 GALEX intrinsic z1.5
# Processed 1P_p28_n1 GALEX intrinsic z1.0
# Processed 1P_p28_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p28_n1 UV1500 intrinsic z2.0
# Processed 1P_p28_n1 UV1500 intrinsic z1.5
# Processed 1P_p28_n1 UV1500 intrinsic z1.0
# Processed 1P_p28_n1 UV1500 intrinsic z0.1
# Processing 1P_p16_n1
# Processing telescope: GALEX
# Processed 1P_p16_n1 GALEX attenuated z2.0
# Processed 1P_p16_n1 GALEX attenuated z1.5
# Processed 1P_p16_n1 GALEX attenuated z1.0
# Processed 1P_p16_n1 GALEX attenuated z0.1
# Processed 1P_p16_n1 GALEX intrinsic z2.0
# Processed 1P_p16_n1 GALEX intrinsic z1.5
# Processed 1P_p16_n1 GALEX intrinsic z1.0
# Processed 1P_p16_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p16_n1 UV1500 intrinsic z2.0
# Processed 1P_p16_n1 UV1500 intrinsic z1.5
# Processed 1P_p16_n1 UV1500 intrinsic z1.0
# Processed 1P_p16_n1 UV1500 intrinsic z0.1
# Processing 1P_p21_n2
# Processing telescope: GALEX
# Processed 1P_p21_n2 GALEX attenuated z2.0
# Processed 1P_p21_n2 GALEX attenuated z1.5
# Processed 1P_p21_n2 GALEX attenuated z1.0
# Processed 1P_p21_n2 GALEX attenuated z0.1
# Processed 1P_p21_n2 GALEX intrinsic z2.0
# Processed 1P_p21_n2 GALEX intrinsic z1.5
# Processed 1P_p21_n2 GALEX intrinsic z1.0
# Processed 1P_p21_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p21_n2 UV1500 intrinsic z2.0
# Processed 1P_p21_n2 UV1500 intrinsic z1.5
# Processed 1P_p21_n2 UV1500 intrinsic z1.0
# Processed 1P_p21_n2 UV1500 intrinsic z0.1
# Processing 1P_p2_n1
# Processing telescope: GALEX
# Processed 1P_p2_n1 GALEX attenuated z2.0
# Processed 1P_p2_n1 GALEX attenuated z1.5
# Processed 1P_p2_n1 GALEX attenuated z1.0
# Processed 1P_p2_n1 GALEX attenuated z0.1
# Processed 1P_p2_n1 GALEX intrinsic z2.0
# Processed 1P_p2_n1 GALEX intrinsic z1.5
# Processed 1P_p2_n1 GALEX intrinsic z1.0
# Processed 1P_p2_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p2_n1 UV1500 intrinsic z2.0
# Processed 1P_p2_n1 UV1500 intrinsic z1.5
# Processed 1P_p2_n1 UV1500 intrinsic z1.0
# Processed 1P_p2_n1 UV1500 intrinsic z0.1
# Processing 1P_p1_1
# Processing telescope: GALEX
# Processed 1P_p1_1 GALEX attenuated z2.0
# Processed 1P_p1_1 GALEX attenuated z1.5
# Processed 1P_p1_1 GALEX attenuated z1.0
# Processed 1P_p1_1 GALEX attenuated z0.1
# Processed 1P_p1_1 GALEX intrinsic z2.0
# Processed 1P_p1_1 GALEX intrinsic z1.5
# Processed 1P_p1_1 GALEX intrinsic z1.0
# Processed 1P_p1_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p1_1 UV1500 intrinsic z2.0
# Processed 1P_p1_1 UV1500 intrinsic z1.5
# Processed 1P_p1_1 UV1500 intrinsic z1.0
# Processed 1P_p1_1 UV1500 intrinsic z0.1
# Processing 1P_p6_2
# Processing telescope: GALEX
# Processed 1P_p6_2 GALEX attenuated z2.0
# Processed 1P_p6_2 GALEX attenuated z1.5
# Processed 1P_p6_2 GALEX attenuated z1.0
# Processed 1P_p6_2 GALEX attenuated z0.1
# Processed 1P_p6_2 GALEX intrinsic z2.0
# Processed 1P_p6_2 GALEX intrinsic z1.5
# Processed 1P_p6_2 GALEX intrinsic z1.0
# Processed 1P_p6_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p6_2 UV1500 intrinsic z2.0
# Processed 1P_p6_2 UV1500 intrinsic z1.5
# Processed 1P_p6_2 UV1500 intrinsic z1.0
# Processed 1P_p6_2 UV1500 intrinsic z0.1
# Processing 1P_p2_n2
# Processing telescope: GALEX
# Processed 1P_p2_n2 GALEX attenuated z2.0
# Processed 1P_p2_n2 GALEX attenuated z1.5
# Processed 1P_p2_n2 GALEX attenuated z1.0
# Processed 1P_p2_n2 GALEX attenuated z0.1
# Processed 1P_p2_n2 GALEX intrinsic z2.0
# Processed 1P_p2_n2 GALEX intrinsic z1.5
# Processed 1P_p2_n2 GALEX intrinsic z1.0
# Processed 1P_p2_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p2_n2 UV1500 intrinsic z2.0
# Processed 1P_p2_n2 UV1500 intrinsic z1.5
# Processed 1P_p2_n2 UV1500 intrinsic z1.0
# Processed 1P_p2_n2 UV1500 intrinsic z0.1
# Processing 1P_p21_n1
# Processing telescope: GALEX
# Processed 1P_p21_n1 GALEX attenuated z2.0
# Processed 1P_p21_n1 GALEX attenuated z1.5
# Processed 1P_p21_n1 GALEX attenuated z1.0
# Processed 1P_p21_n1 GALEX attenuated z0.1
# Processed 1P_p21_n1 GALEX intrinsic z2.0
# Processed 1P_p21_n1 GALEX intrinsic z1.5
# Processed 1P_p21_n1 GALEX intrinsic z1.0
# Processed 1P_p21_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p21_n1 UV1500 intrinsic z2.0
# Processed 1P_p21_n1 UV1500 intrinsic z1.5
# Processed 1P_p21_n1 UV1500 intrinsic z1.0
# Processed 1P_p21_n1 UV1500 intrinsic z0.1
# Processing 1P_p16_n2
# Processing telescope: GALEX
# Processed 1P_p16_n2 GALEX attenuated z2.0
# Processed 1P_p16_n2 GALEX attenuated z1.5
# Processed 1P_p16_n2 GALEX attenuated z1.0
# Processed 1P_p16_n2 GALEX attenuated z0.1
# Processed 1P_p16_n2 GALEX intrinsic z2.0
# Processed 1P_p16_n2 GALEX intrinsic z1.5
# Processed 1P_p16_n2 GALEX intrinsic z1.0
# Processed 1P_p16_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p16_n2 UV1500 intrinsic z2.0
# Processed 1P_p16_n2 UV1500 intrinsic z1.5
# Processed 1P_p16_n2 UV1500 intrinsic z1.0
# Processed 1P_p16_n2 UV1500 intrinsic z0.1
# Processing 1P_p28_n2
# Processing telescope: GALEX
# Processed 1P_p28_n2 GALEX attenuated z2.0
# Processed 1P_p28_n2 GALEX attenuated z1.5
# Processed 1P_p28_n2 GALEX attenuated z1.0
# Processed 1P_p28_n2 GALEX attenuated z0.1
# Processed 1P_p28_n2 GALEX intrinsic z2.0
# Processed 1P_p28_n2 GALEX intrinsic z1.5
# Processed 1P_p28_n2 GALEX intrinsic z1.0
# Processed 1P_p28_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p28_n2 UV1500 intrinsic z2.0
# Processed 1P_p28_n2 UV1500 intrinsic z1.5
# Processed 1P_p28_n2 UV1500 intrinsic z1.0
# Processed 1P_p28_n2 UV1500 intrinsic z0.1
# Processing 1P_p7_n1
# Processing telescope: GALEX
# Processed 1P_p7_n1 GALEX attenuated z2.0
# Processed 1P_p7_n1 GALEX attenuated z1.5
# Processed 1P_p7_n1 GALEX attenuated z1.0
# Processed 1P_p7_n1 GALEX attenuated z0.1
# Processed 1P_p7_n1 GALEX intrinsic z2.0
# Processed 1P_p7_n1 GALEX intrinsic z1.5
# Processed 1P_p7_n1 GALEX intrinsic z1.0
# Processed 1P_p7_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p7_n1 UV1500 intrinsic z2.0
# Processed 1P_p7_n1 UV1500 intrinsic z1.5
# Processed 1P_p7_n1 UV1500 intrinsic z1.0
# Processed 1P_p7_n1 UV1500 intrinsic z0.1
# Processing 1P_p11_1
# Processing telescope: GALEX
# Processed 1P_p11_1 GALEX attenuated z2.0
# Processed 1P_p11_1 GALEX attenuated z1.5
# Processed 1P_p11_1 GALEX attenuated z1.0
# Processed 1P_p11_1 GALEX attenuated z0.1
# Processed 1P_p11_1 GALEX intrinsic z2.0
# Processed 1P_p11_1 GALEX intrinsic z1.5
# Processed 1P_p11_1 GALEX intrinsic z1.0
# Processed 1P_p11_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p11_1 UV1500 intrinsic z2.0
# Processed 1P_p11_1 UV1500 intrinsic z1.5
# Processed 1P_p11_1 UV1500 intrinsic z1.0
# Processed 1P_p11_1 UV1500 intrinsic z0.1
# Processing 1P_p24_n2
# Processing telescope: GALEX
# Processed 1P_p24_n2 GALEX attenuated z2.0
# Processed 1P_p24_n2 GALEX attenuated z1.5
# Processed 1P_p24_n2 GALEX attenuated z1.0
# Processed 1P_p24_n2 GALEX attenuated z0.1
# Processed 1P_p24_n2 GALEX intrinsic z2.0
# Processed 1P_p24_n2 GALEX intrinsic z1.5
# Processed 1P_p24_n2 GALEX intrinsic z1.0
# Processed 1P_p24_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p24_n2 UV1500 intrinsic z2.0
# Processed 1P_p24_n2 UV1500 intrinsic z1.5
# Processed 1P_p24_n2 UV1500 intrinsic z1.0
# Processed 1P_p24_n2 UV1500 intrinsic z0.1
# Processing 1P_p16_2
# Processing telescope: GALEX
# Processed 1P_p16_2 GALEX attenuated z2.0
# Processed 1P_p16_2 GALEX attenuated z1.5
# Processed 1P_p16_2 GALEX attenuated z1.0
# Processed 1P_p16_2 GALEX attenuated z0.1
# Processed 1P_p16_2 GALEX intrinsic z2.0
# Processed 1P_p16_2 GALEX intrinsic z1.5
# Processed 1P_p16_2 GALEX intrinsic z1.0
# Processed 1P_p16_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p16_2 UV1500 intrinsic z2.0
# Processed 1P_p16_2 UV1500 intrinsic z1.5
# Processed 1P_p16_2 UV1500 intrinsic z1.0
# Processed 1P_p16_2 UV1500 intrinsic z0.1
# Processing 1P_p13_n1
# Processing telescope: GALEX
# Processed 1P_p13_n1 GALEX attenuated z2.0
# Processed 1P_p13_n1 GALEX attenuated z1.5
# Processed 1P_p13_n1 GALEX attenuated z1.0
# Processed 1P_p13_n1 GALEX attenuated z0.1
# Processed 1P_p13_n1 GALEX intrinsic z2.0
# Processed 1P_p13_n1 GALEX intrinsic z1.5
# Processed 1P_p13_n1 GALEX intrinsic z1.0
# Processed 1P_p13_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p13_n1 UV1500 intrinsic z2.0
# Processed 1P_p13_n1 UV1500 intrinsic z1.5
# Processed 1P_p13_n1 UV1500 intrinsic z1.0
# Processed 1P_p13_n1 UV1500 intrinsic z0.1
# Processing 1P_p22_2
# Processing telescope: GALEX
# Processed 1P_p22_2 GALEX attenuated z2.0
# Processed 1P_p22_2 GALEX attenuated z1.5
# Processed 1P_p22_2 GALEX attenuated z1.0
# Processed 1P_p22_2 GALEX attenuated z0.1
# Processed 1P_p22_2 GALEX intrinsic z2.0
# Processed 1P_p22_2 GALEX intrinsic z1.5
# Processed 1P_p22_2 GALEX intrinsic z1.0
# Processed 1P_p22_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p22_2 UV1500 intrinsic z2.0
# Processed 1P_p22_2 UV1500 intrinsic z1.5
# Processed 1P_p22_2 UV1500 intrinsic z1.0
# Processed 1P_p22_2 UV1500 intrinsic z0.1
# Processing 1P_p25_1
# Processing telescope: GALEX
# Processed 1P_p25_1 GALEX attenuated z2.0
# Processed 1P_p25_1 GALEX attenuated z1.5
# Processed 1P_p25_1 GALEX attenuated z1.0
# Processed 1P_p25_1 GALEX attenuated z0.1
# Processed 1P_p25_1 GALEX intrinsic z2.0
# Processed 1P_p25_1 GALEX intrinsic z1.5
# Processed 1P_p25_1 GALEX intrinsic z1.0
# Processed 1P_p25_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p25_1 UV1500 intrinsic z2.0
# Processed 1P_p25_1 UV1500 intrinsic z1.5
# Processed 1P_p25_1 UV1500 intrinsic z1.0
# Processed 1P_p25_1 UV1500 intrinsic z0.1
# Processing 1P_p26_n1
# Processing telescope: GALEX
# Processed 1P_p26_n1 GALEX attenuated z2.0
# Processed 1P_p26_n1 GALEX attenuated z1.5
# Processed 1P_p26_n1 GALEX attenuated z1.0
# Processed 1P_p26_n1 GALEX attenuated z0.1
# Processed 1P_p26_n1 GALEX intrinsic z2.0
# Processed 1P_p26_n1 GALEX intrinsic z1.5
# Processed 1P_p26_n1 GALEX intrinsic z1.0
# Processed 1P_p26_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p26_n1 UV1500 intrinsic z2.0
# Processed 1P_p26_n1 UV1500 intrinsic z1.5
# Processed 1P_p26_n1 UV1500 intrinsic z1.0
# Processed 1P_p26_n1 UV1500 intrinsic z0.1
# Processing 1P_p18_n1
# Processing telescope: GALEX
# Processed 1P_p18_n1 GALEX attenuated z2.0
# Processed 1P_p18_n1 GALEX attenuated z1.5
# Processed 1P_p18_n1 GALEX attenuated z1.0
# Processed 1P_p18_n1 GALEX attenuated z0.1
# Processed 1P_p18_n1 GALEX intrinsic z2.0
# Processed 1P_p18_n1 GALEX intrinsic z1.5
# Processed 1P_p18_n1 GALEX intrinsic z1.0
# Processed 1P_p18_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p18_n1 UV1500 intrinsic z2.0
# Processed 1P_p18_n1 UV1500 intrinsic z1.5
# Processed 1P_p18_n1 UV1500 intrinsic z1.0
# Processed 1P_p18_n1 UV1500 intrinsic z0.1
# Processing 1P_p11_n2
# Processing telescope: GALEX
# Processed 1P_p11_n2 GALEX attenuated z2.0
# Processed 1P_p11_n2 GALEX attenuated z1.5
# Processed 1P_p11_n2 GALEX attenuated z1.0
# Processed 1P_p11_n2 GALEX attenuated z0.1
# Processed 1P_p11_n2 GALEX intrinsic z2.0
# Processed 1P_p11_n2 GALEX intrinsic z1.5
# Processed 1P_p11_n2 GALEX intrinsic z1.0
# Processed 1P_p11_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p11_n2 UV1500 intrinsic z2.0
# Processed 1P_p11_n2 UV1500 intrinsic z1.5
# Processed 1P_p11_n2 UV1500 intrinsic z1.0
# Processed 1P_p11_n2 UV1500 intrinsic z0.1
# Processing 1P_p23_1
# Processing telescope: GALEX
# Processed 1P_p23_1 GALEX attenuated z2.0
# Processed 1P_p23_1 GALEX attenuated z1.5
# Processed 1P_p23_1 GALEX attenuated z1.0
# Processed 1P_p23_1 GALEX attenuated z0.1
# Processed 1P_p23_1 GALEX intrinsic z2.0
# Processed 1P_p23_1 GALEX intrinsic z1.5
# Processed 1P_p23_1 GALEX intrinsic z1.0
# Processed 1P_p23_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p23_1 UV1500 intrinsic z2.0
# Processed 1P_p23_1 UV1500 intrinsic z1.5
# Processed 1P_p23_1 UV1500 intrinsic z1.0
# Processed 1P_p23_1 UV1500 intrinsic z0.1
# Processing 1P_p5_n2
# Processing telescope: GALEX
# Processed 1P_p5_n2 GALEX attenuated z2.0
# Processed 1P_p5_n2 GALEX attenuated z1.5
# Processed 1P_p5_n2 GALEX attenuated z1.0
# Processed 1P_p5_n2 GALEX attenuated z0.1
# Processed 1P_p5_n2 GALEX intrinsic z2.0
# Processed 1P_p5_n2 GALEX intrinsic z1.5
# Processed 1P_p5_n2 GALEX intrinsic z1.0
# Processed 1P_p5_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p5_n2 UV1500 intrinsic z2.0
# Processed 1P_p5_n2 UV1500 intrinsic z1.5
# Processed 1P_p5_n2 UV1500 intrinsic z1.0
# Processed 1P_p5_n2 UV1500 intrinsic z0.1
# Processing 1P_p24_2
# Processing telescope: GALEX
# Processed 1P_p24_2 GALEX attenuated z2.0
# Processed 1P_p24_2 GALEX attenuated z1.5
# Processed 1P_p24_2 GALEX attenuated z1.0
# Processed 1P_p24_2 GALEX attenuated z0.1
# Processed 1P_p24_2 GALEX intrinsic z2.0
# Processed 1P_p24_2 GALEX intrinsic z1.5
# Processed 1P_p24_2 GALEX intrinsic z1.0
# Processed 1P_p24_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p24_2 UV1500 intrinsic z2.0
# Processed 1P_p24_2 UV1500 intrinsic z1.5
# Processed 1P_p24_2 UV1500 intrinsic z1.0
# Processed 1P_p24_2 UV1500 intrinsic z0.1
# Processing 1P_p28_1
# Processing telescope: GALEX
# Processed 1P_p28_1 GALEX attenuated z2.0
# Processed 1P_p28_1 GALEX attenuated z1.5
# Processed 1P_p28_1 GALEX attenuated z1.0
# Processed 1P_p28_1 GALEX attenuated z0.1
# Processed 1P_p28_1 GALEX intrinsic z2.0
# Processed 1P_p28_1 GALEX intrinsic z1.5
# Processed 1P_p28_1 GALEX intrinsic z1.0
# Processed 1P_p28_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p28_1 UV1500 intrinsic z2.0
# Processed 1P_p28_1 UV1500 intrinsic z1.5
# Processed 1P_p28_1 UV1500 intrinsic z1.0
# Processed 1P_p28_1 UV1500 intrinsic z0.1
# Processing 1P_p10_2
# Processing telescope: GALEX
# Processed 1P_p10_2 GALEX attenuated z2.0
# Processed 1P_p10_2 GALEX attenuated z1.5
# Processed 1P_p10_2 GALEX attenuated z1.0
# Processed 1P_p10_2 GALEX attenuated z0.1
# Processed 1P_p10_2 GALEX intrinsic z2.0
# Processed 1P_p10_2 GALEX intrinsic z1.5
# Processed 1P_p10_2 GALEX intrinsic z1.0
# Processed 1P_p10_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p10_2 UV1500 intrinsic z2.0
# Processed 1P_p10_2 UV1500 intrinsic z1.5
# Processed 1P_p10_2 UV1500 intrinsic z1.0
# Processed 1P_p10_2 UV1500 intrinsic z0.1
# Processing 1P_p1_0
# Processing telescope: GALEX
# Processed 1P_p1_0 GALEX attenuated z2.0
# Processed 1P_p1_0 GALEX attenuated z1.5
# Processed 1P_p1_0 GALEX attenuated z1.0
# Processed 1P_p1_0 GALEX attenuated z0.1
# Processed 1P_p1_0 GALEX intrinsic z2.0
# Processed 1P_p1_0 GALEX intrinsic z1.5
# Processed 1P_p1_0 GALEX intrinsic z1.0
# Processed 1P_p1_0 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p1_0 UV1500 intrinsic z2.0
# Processed 1P_p1_0 UV1500 intrinsic z1.5
# Processed 1P_p1_0 UV1500 intrinsic z1.0
# Processed 1P_p1_0 UV1500 intrinsic z0.1
# Processing 1P_p17_1
# Processing telescope: GALEX
# Processed 1P_p17_1 GALEX attenuated z2.0
# Processed 1P_p17_1 GALEX attenuated z1.5
# Processed 1P_p17_1 GALEX attenuated z1.0
# Processed 1P_p17_1 GALEX attenuated z0.1
# Processed 1P_p17_1 GALEX intrinsic z2.0
# Processed 1P_p17_1 GALEX intrinsic z1.5
# Processed 1P_p17_1 GALEX intrinsic z1.0
# Processed 1P_p17_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p17_1 UV1500 intrinsic z2.0
# Processed 1P_p17_1 UV1500 intrinsic z1.5
# Processed 1P_p17_1 UV1500 intrinsic z1.0
# Processed 1P_p17_1 UV1500 intrinsic z0.1
# Processing 1P_p23_n2
# Processing telescope: GALEX
# Processed 1P_p23_n2 GALEX attenuated z2.0
# Processed 1P_p23_n2 GALEX attenuated z1.5
# Processed 1P_p23_n2 GALEX attenuated z1.0
# Processed 1P_p23_n2 GALEX attenuated z0.1
# Processed 1P_p23_n2 GALEX intrinsic z2.0
# Processed 1P_p23_n2 GALEX intrinsic z1.5
# Processed 1P_p23_n2 GALEX intrinsic z1.0
# Processed 1P_p23_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p23_n2 UV1500 intrinsic z2.0
# Processed 1P_p23_n2 UV1500 intrinsic z1.5
# Processed 1P_p23_n2 UV1500 intrinsic z1.0
# Processed 1P_p23_n2 UV1500 intrinsic z0.1
# Processing 1P_p14_n1
# Processing telescope: GALEX
# Processed 1P_p14_n1 GALEX attenuated z2.0
# Processed 1P_p14_n1 GALEX attenuated z1.5
# Processed 1P_p14_n1 GALEX attenuated z1.0
# Processed 1P_p14_n1 GALEX attenuated z0.1
# Processed 1P_p14_n1 GALEX intrinsic z2.0
# Processed 1P_p14_n1 GALEX intrinsic z1.5
# Processed 1P_p14_n1 GALEX intrinsic z1.0
# Processed 1P_p14_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p14_n1 UV1500 intrinsic z2.0
# Processed 1P_p14_n1 UV1500 intrinsic z1.5
# Processed 1P_p14_n1 UV1500 intrinsic z1.0
# Processed 1P_p14_n1 UV1500 intrinsic z0.1
# Processing 1P_p7_1
# Processing telescope: GALEX
# Processed 1P_p7_1 GALEX attenuated z2.0
# Processed 1P_p7_1 GALEX attenuated z1.5
# Processed 1P_p7_1 GALEX attenuated z1.0
# Processed 1P_p7_1 GALEX attenuated z0.1
# Processed 1P_p7_1 GALEX intrinsic z2.0
# Processed 1P_p7_1 GALEX intrinsic z1.5
# Processed 1P_p7_1 GALEX intrinsic z1.0
# Processed 1P_p7_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p7_1 UV1500 intrinsic z2.0
# Processed 1P_p7_1 UV1500 intrinsic z1.5
# Processed 1P_p7_1 UV1500 intrinsic z1.0
# Processed 1P_p7_1 UV1500 intrinsic z0.1
# Processing 1P_p9_n2
# Processing telescope: GALEX
# Processed 1P_p9_n2 GALEX attenuated z2.0
# Processed 1P_p9_n2 GALEX attenuated z1.5
# Processed 1P_p9_n2 GALEX attenuated z1.0
# Processed 1P_p9_n2 GALEX attenuated z0.1
# Processed 1P_p9_n2 GALEX intrinsic z2.0
# Processed 1P_p9_n2 GALEX intrinsic z1.5
# Processed 1P_p9_n2 GALEX intrinsic z1.0
# Processed 1P_p9_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p9_n2 UV1500 intrinsic z2.0
# Processed 1P_p9_n2 UV1500 intrinsic z1.5
# Processed 1P_p9_n2 UV1500 intrinsic z1.0
# Processed 1P_p9_n2 UV1500 intrinsic z0.1
# Processing 1P_p15_2
# Processing telescope: GALEX
# Processed 1P_p15_2 GALEX attenuated z2.0
# Processed 1P_p15_2 GALEX attenuated z1.5
# Processed 1P_p15_2 GALEX attenuated z1.0
# Processed 1P_p15_2 GALEX attenuated z0.1
# Processed 1P_p15_2 GALEX intrinsic z2.0
# Processed 1P_p15_2 GALEX intrinsic z1.5
# Processed 1P_p15_2 GALEX intrinsic z1.0
# Processed 1P_p15_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p15_2 UV1500 intrinsic z2.0
# Processed 1P_p15_2 UV1500 intrinsic z1.5
# Processed 1P_p15_2 UV1500 intrinsic z1.0
# Processed 1P_p15_2 UV1500 intrinsic z0.1
# Processing 1P_p12_1
# Processing telescope: GALEX
# Processed 1P_p12_1 GALEX attenuated z2.0
# Processed 1P_p12_1 GALEX attenuated z1.5
# Processed 1P_p12_1 GALEX attenuated z1.0
# Processed 1P_p12_1 GALEX attenuated z0.1
# Processed 1P_p12_1 GALEX intrinsic z2.0
# Processed 1P_p12_1 GALEX intrinsic z1.5
# Processed 1P_p12_1 GALEX intrinsic z1.0
# Processed 1P_p12_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p12_1 UV1500 intrinsic z2.0
# Processed 1P_p12_1 UV1500 intrinsic z1.5
# Processed 1P_p12_1 UV1500 intrinsic z1.0
# Processed 1P_p12_1 UV1500 intrinsic z0.1
# Processing 1P_p27_n1
# Processing telescope: GALEX
# Processed 1P_p27_n1 GALEX attenuated z2.0
# Processed 1P_p27_n1 GALEX attenuated z1.5
# Processed 1P_p27_n1 GALEX attenuated z1.0
# Processed 1P_p27_n1 GALEX attenuated z0.1
# Processed 1P_p27_n1 GALEX intrinsic z2.0
# Processed 1P_p27_n1 GALEX intrinsic z1.5
# Processed 1P_p27_n1 GALEX intrinsic z1.0
# Processed 1P_p27_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p27_n1 UV1500 intrinsic z2.0
# Processed 1P_p27_n1 UV1500 intrinsic z1.5
# Processed 1P_p27_n1 UV1500 intrinsic z1.0
# Processed 1P_p27_n1 UV1500 intrinsic z0.1
# Processing 1P_p19_n1
# Processing telescope: GALEX
# Processed 1P_p19_n1 GALEX attenuated z2.0
# Processed 1P_p19_n1 GALEX attenuated z1.5
# Processed 1P_p19_n1 GALEX attenuated z1.0
# Processed 1P_p19_n1 GALEX attenuated z0.1
# Processed 1P_p19_n1 GALEX intrinsic z2.0
# Processed 1P_p19_n1 GALEX intrinsic z1.5
# Processed 1P_p19_n1 GALEX intrinsic z1.0
# Processed 1P_p19_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p19_n1 UV1500 intrinsic z2.0
# Processed 1P_p19_n1 UV1500 intrinsic z1.5
# Processed 1P_p19_n1 UV1500 intrinsic z1.0
# Processed 1P_p19_n1 UV1500 intrinsic z0.1
# Processing 1P_p26_1
# Processing telescope: GALEX
# Processed 1P_p26_1 GALEX attenuated z2.0
# Processed 1P_p26_1 GALEX attenuated z1.5
# Processed 1P_p26_1 GALEX attenuated z1.0
# Processed 1P_p26_1 GALEX attenuated z0.1
# Processed 1P_p26_1 GALEX intrinsic z2.0
# Processed 1P_p26_1 GALEX intrinsic z1.5
# Processed 1P_p26_1 GALEX intrinsic z1.0
# Processed 1P_p26_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p26_1 UV1500 intrinsic z2.0
# Processed 1P_p26_1 UV1500 intrinsic z1.5
# Processed 1P_p26_1 UV1500 intrinsic z1.0
# Processed 1P_p26_1 UV1500 intrinsic z0.1
# Processing 1P_p10_n2
# Processing telescope: GALEX
# Processed 1P_p10_n2 GALEX attenuated z2.0
# Processed 1P_p10_n2 GALEX attenuated z1.5
# Processed 1P_p10_n2 GALEX attenuated z1.0
# Processed 1P_p10_n2 GALEX attenuated z0.1
# Processed 1P_p10_n2 GALEX intrinsic z2.0
# Processed 1P_p10_n2 GALEX intrinsic z1.5
# Processed 1P_p10_n2 GALEX intrinsic z1.0
# Processed 1P_p10_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p10_n2 UV1500 intrinsic z2.0
# Processed 1P_p10_n2 UV1500 intrinsic z1.5
# Processed 1P_p10_n2 UV1500 intrinsic z1.0
# Processed 1P_p10_n2 UV1500 intrinsic z0.1
# Processing 1P_p4_n2
# Processing telescope: GALEX
# Processed 1P_p4_n2 GALEX attenuated z2.0
# Processed 1P_p4_n2 GALEX attenuated z1.5
# Processed 1P_p4_n2 GALEX attenuated z1.0
# Processed 1P_p4_n2 GALEX attenuated z0.1
# Processed 1P_p4_n2 GALEX intrinsic z2.0
# Processed 1P_p4_n2 GALEX intrinsic z1.5
# Processed 1P_p4_n2 GALEX intrinsic z1.0
# Processed 1P_p4_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p4_n2 UV1500 intrinsic z2.0
# Processed 1P_p4_n2 UV1500 intrinsic z1.5
# Processed 1P_p4_n2 UV1500 intrinsic z1.0
# Processed 1P_p4_n2 UV1500 intrinsic z0.1
# Processing 1P_p19_1
# Processing telescope: GALEX
# Processed 1P_p19_1 GALEX attenuated z2.0
# Processed 1P_p19_1 GALEX attenuated z1.5
# Processed 1P_p19_1 GALEX attenuated z1.0
# Processed 1P_p19_1 GALEX attenuated z0.1
# Processed 1P_p19_1 GALEX intrinsic z2.0
# Processed 1P_p19_1 GALEX intrinsic z1.5
# Processed 1P_p19_1 GALEX intrinsic z1.0
# Processed 1P_p19_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p19_1 UV1500 intrinsic z2.0
# Processed 1P_p19_1 UV1500 intrinsic z1.5
# Processed 1P_p19_1 UV1500 intrinsic z1.0
# Processed 1P_p19_1 UV1500 intrinsic z0.1
# Processing 1P_p21_2
# Processing telescope: GALEX
# Processed 1P_p21_2 GALEX attenuated z2.0
# Processed 1P_p21_2 GALEX attenuated z1.5
# Processed 1P_p21_2 GALEX attenuated z1.0
# Processed 1P_p21_2 GALEX attenuated z0.1
# Processed 1P_p21_2 GALEX intrinsic z2.0
# Processed 1P_p21_2 GALEX intrinsic z1.5
# Processed 1P_p21_2 GALEX intrinsic z1.0
# Processed 1P_p21_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p21_2 UV1500 intrinsic z2.0
# Processed 1P_p21_2 UV1500 intrinsic z1.5
# Processed 1P_p21_2 UV1500 intrinsic z1.0
# Processed 1P_p21_2 UV1500 intrinsic z0.1
# Processing 1P_p22_n2
# Processing telescope: GALEX
# Processed 1P_p22_n2 GALEX attenuated z2.0
# Processed 1P_p22_n2 GALEX attenuated z1.5
# Processed 1P_p22_n2 GALEX attenuated z1.0
# Processed 1P_p22_n2 GALEX attenuated z0.1
# Processed 1P_p22_n2 GALEX intrinsic z2.0
# Processed 1P_p22_n2 GALEX intrinsic z1.5
# Processed 1P_p22_n2 GALEX intrinsic z1.0
# Processed 1P_p22_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p22_n2 UV1500 intrinsic z2.0
# Processed 1P_p22_n2 UV1500 intrinsic z1.5
# Processed 1P_p22_n2 UV1500 intrinsic z1.0
# Processed 1P_p22_n2 UV1500 intrinsic z0.1
# Processing 1P_p5_2
# Processing telescope: GALEX
# Processed 1P_p5_2 GALEX attenuated z2.0
# Processed 1P_p5_2 GALEX attenuated z1.5
# Processed 1P_p5_2 GALEX attenuated z1.0
# Processed 1P_p5_2 GALEX attenuated z0.1
# Processed 1P_p5_2 GALEX intrinsic z2.0
# Processed 1P_p5_2 GALEX intrinsic z1.5
# Processed 1P_p5_2 GALEX intrinsic z1.0
# Processed 1P_p5_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p5_2 UV1500 intrinsic z2.0
# Processed 1P_p5_2 UV1500 intrinsic z1.5
# Processed 1P_p5_2 UV1500 intrinsic z1.0
# Processed 1P_p5_2 UV1500 intrinsic z0.1
# Processing 1P_p1_n1
# Processing telescope: GALEX
# Processed 1P_p1_n1 GALEX attenuated z2.0
# Processed 1P_p1_n1 GALEX attenuated z1.5
# Processed 1P_p1_n1 GALEX attenuated z1.0
# Processed 1P_p1_n1 GALEX attenuated z0.1
# Processed 1P_p1_n1 GALEX intrinsic z2.0
# Processed 1P_p1_n1 GALEX intrinsic z1.5
# Processed 1P_p1_n1 GALEX intrinsic z1.0
# Processed 1P_p1_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p1_n1 UV1500 intrinsic z2.0
# Processed 1P_p1_n1 UV1500 intrinsic z1.5
# Processed 1P_p1_n1 UV1500 intrinsic z1.0
# Processed 1P_p1_n1 UV1500 intrinsic z0.1
# Processing 1P_p2_1
# Processing telescope: GALEX
# Processed 1P_p2_1 GALEX attenuated z2.0
# Processed 1P_p2_1 GALEX attenuated z1.5
# Processed 1P_p2_1 GALEX attenuated z1.0
# Processed 1P_p2_1 GALEX attenuated z0.1
# Processed 1P_p2_1 GALEX intrinsic z2.0
# Processed 1P_p2_1 GALEX intrinsic z1.5
# Processed 1P_p2_1 GALEX intrinsic z1.0
# Processed 1P_p2_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p2_1 UV1500 intrinsic z2.0
# Processed 1P_p2_1 UV1500 intrinsic z1.5
# Processed 1P_p2_1 UV1500 intrinsic z1.0
# Processed 1P_p2_1 UV1500 intrinsic z0.1
# Processing 1P_p8_n2
# Processing telescope: GALEX
# Processed 1P_p8_n2 GALEX attenuated z2.0
# Processed 1P_p8_n2 GALEX attenuated z1.5
# Processed 1P_p8_n2 GALEX attenuated z1.0
# Processed 1P_p8_n2 GALEX attenuated z0.1
# Processed 1P_p8_n2 GALEX intrinsic z2.0
# Processed 1P_p8_n2 GALEX intrinsic z1.5
# Processed 1P_p8_n2 GALEX intrinsic z1.0
# Processed 1P_p8_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p8_n2 UV1500 intrinsic z2.0
# Processed 1P_p8_n2 UV1500 intrinsic z1.5
# Processed 1P_p8_n2 UV1500 intrinsic z1.0
# Processed 1P_p8_n2 UV1500 intrinsic z0.1
# Processing 1P_p9_1
# Processing telescope: GALEX
# Processed 1P_p9_1 GALEX attenuated z2.0
# Processed 1P_p9_1 GALEX attenuated z1.5
# Processed 1P_p9_1 GALEX attenuated z1.0
# Processed 1P_p9_1 GALEX attenuated z0.1
# Processed 1P_p9_1 GALEX intrinsic z2.0
# Processed 1P_p9_1 GALEX intrinsic z1.5
# Processed 1P_p9_1 GALEX intrinsic z1.0
# Processed 1P_p9_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p9_1 UV1500 intrinsic z2.0
# Processed 1P_p9_1 UV1500 intrinsic z1.5
# Processed 1P_p9_1 UV1500 intrinsic z1.0
# Processed 1P_p9_1 UV1500 intrinsic z0.1
# Processing 1P_p3_n2
# Processing telescope: GALEX
# Processed 1P_p3_n2 GALEX attenuated z2.0
# Processed 1P_p3_n2 GALEX attenuated z1.5
# Processed 1P_p3_n2 GALEX attenuated z1.0
# Processed 1P_p3_n2 GALEX attenuated z0.1
# Processed 1P_p3_n2 GALEX intrinsic z2.0
# Processed 1P_p3_n2 GALEX intrinsic z1.5
# Processed 1P_p3_n2 GALEX intrinsic z1.0
# Processed 1P_p3_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p3_n2 UV1500 intrinsic z2.0
# Processed 1P_p3_n2 UV1500 intrinsic z1.5
# Processed 1P_p3_n2 UV1500 intrinsic z1.0
# Processed 1P_p3_n2 UV1500 intrinsic z0.1
# Processing 1P_p8_2
# Processing telescope: GALEX
# Processed 1P_p8_2 GALEX attenuated z2.0
# Processed 1P_p8_2 GALEX attenuated z1.5
# Processed 1P_p8_2 GALEX attenuated z1.0
# Processed 1P_p8_2 GALEX attenuated z0.1
# Processed 1P_p8_2 GALEX intrinsic z2.0
# Processed 1P_p8_2 GALEX intrinsic z1.5
# Processed 1P_p8_2 GALEX intrinsic z1.0
# Processed 1P_p8_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p8_2 UV1500 intrinsic z2.0
# Processed 1P_p8_2 UV1500 intrinsic z1.5
# Processed 1P_p8_2 UV1500 intrinsic z1.0
# Processed 1P_p8_2 UV1500 intrinsic z0.1
# Processing 1P_p20_n1
# Processing telescope: GALEX
# Processed 1P_p20_n1 GALEX attenuated z2.0
# Processed 1P_p20_n1 GALEX attenuated z1.5
# Processed 1P_p20_n1 GALEX attenuated z1.0
# Processed 1P_p20_n1 GALEX attenuated z0.1
# Processed 1P_p20_n1 GALEX intrinsic z2.0
# Processed 1P_p20_n1 GALEX intrinsic z1.5
# Processed 1P_p20_n1 GALEX intrinsic z1.0
# Processed 1P_p20_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p20_n1 UV1500 intrinsic z2.0
# Processed 1P_p20_n1 UV1500 intrinsic z1.5
# Processed 1P_p20_n1 UV1500 intrinsic z1.0
# Processed 1P_p20_n1 UV1500 intrinsic z0.1
# Processing 1P_p17_n2
# Processing telescope: GALEX
# Processed 1P_p17_n2 GALEX attenuated z2.0
# Processed 1P_p17_n2 GALEX attenuated z1.5
# Processed 1P_p17_n2 GALEX attenuated z1.0
# Processed 1P_p17_n2 GALEX attenuated z0.1
# Processed 1P_p17_n2 GALEX intrinsic z2.0
# Processed 1P_p17_n2 GALEX intrinsic z1.5
# Processed 1P_p17_n2 GALEX intrinsic z1.0
# Processed 1P_p17_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p17_n2 UV1500 intrinsic z2.0
# Processed 1P_p17_n2 UV1500 intrinsic z1.5
# Processed 1P_p17_n2 UV1500 intrinsic z1.0
# Processed 1P_p17_n2 UV1500 intrinsic z0.1
# Processing 1P_p4_1
# Processing telescope: GALEX
# Processed 1P_p4_1 GALEX attenuated z2.0
# Processed 1P_p4_1 GALEX attenuated z1.5
# Processed 1P_p4_1 GALEX attenuated z1.0
# Processed 1P_p4_1 GALEX attenuated z0.1
# Processed 1P_p4_1 GALEX intrinsic z2.0
# Processed 1P_p4_1 GALEX intrinsic z1.5
# Processed 1P_p4_1 GALEX intrinsic z1.0
# Processed 1P_p4_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p4_1 UV1500 intrinsic z2.0
# Processed 1P_p4_1 UV1500 intrinsic z1.5
# Processed 1P_p4_1 UV1500 intrinsic z1.0
# Processed 1P_p4_1 UV1500 intrinsic z0.1
# Processing 1P_p3_2
# Processing telescope: GALEX
# Processed 1P_p3_2 GALEX attenuated z2.0
# Processed 1P_p3_2 GALEX attenuated z1.5
# Processed 1P_p3_2 GALEX attenuated z1.0
# Processed 1P_p3_2 GALEX attenuated z0.1
# Processed 1P_p3_2 GALEX intrinsic z2.0
# Processed 1P_p3_2 GALEX intrinsic z1.5
# Processed 1P_p3_2 GALEX intrinsic z1.0
# Processed 1P_p3_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p3_2 UV1500 intrinsic z2.0
# Processed 1P_p3_2 UV1500 intrinsic z1.5
# Processed 1P_p3_2 UV1500 intrinsic z1.0
# Processed 1P_p3_2 UV1500 intrinsic z0.1
# Processing 1P_p27_2
# Processing telescope: GALEX
# Processed 1P_p27_2 GALEX attenuated z2.0
# Processed 1P_p27_2 GALEX attenuated z1.5
# Processed 1P_p27_2 GALEX attenuated z1.0
# Processed 1P_p27_2 GALEX attenuated z0.1
# Processed 1P_p27_2 GALEX intrinsic z2.0
# Processed 1P_p27_2 GALEX intrinsic z1.5
# Processed 1P_p27_2 GALEX intrinsic z1.0
# Processed 1P_p27_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p27_2 UV1500 intrinsic z2.0
# Processed 1P_p27_2 UV1500 intrinsic z1.5
# Processed 1P_p27_2 UV1500 intrinsic z1.0
# Processed 1P_p27_2 UV1500 intrinsic z0.1
# Processing 1P_p20_1
# Processing telescope: GALEX
# Processed 1P_p20_1 GALEX attenuated z2.0
# Processed 1P_p20_1 GALEX attenuated z1.5
# Processed 1P_p20_1 GALEX attenuated z1.0
# Processed 1P_p20_1 GALEX attenuated z0.1
# Processed 1P_p20_1 GALEX intrinsic z2.0
# Processed 1P_p20_1 GALEX intrinsic z1.5
# Processed 1P_p20_1 GALEX intrinsic z1.0
# Processed 1P_p20_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p20_1 UV1500 intrinsic z2.0
# Processed 1P_p20_1 UV1500 intrinsic z1.5
# Processed 1P_p20_1 UV1500 intrinsic z1.0
# Processed 1P_p20_1 UV1500 intrinsic z0.1
# Processing 1P_p18_2
# Processing telescope: GALEX
# Processed 1P_p18_2 GALEX attenuated z2.0
# Processed 1P_p18_2 GALEX attenuated z1.5
# Processed 1P_p18_2 GALEX attenuated z1.0
# Processed 1P_p18_2 GALEX attenuated z0.1
# Processed 1P_p18_2 GALEX intrinsic z2.0
# Processed 1P_p18_2 GALEX intrinsic z1.5
# Processed 1P_p18_2 GALEX intrinsic z1.0
# Processed 1P_p18_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p18_2 UV1500 intrinsic z2.0
# Processed 1P_p18_2 UV1500 intrinsic z1.5
# Processed 1P_p18_2 UV1500 intrinsic z1.0
# Processed 1P_p18_2 UV1500 intrinsic z0.1
# Processing 1P_p6_n1
# Processing telescope: GALEX
# Processed 1P_p6_n1 GALEX attenuated z2.0
# Processed 1P_p6_n1 GALEX attenuated z1.5
# Processed 1P_p6_n1 GALEX attenuated z1.0
# Processed 1P_p6_n1 GALEX attenuated z0.1
# Processed 1P_p6_n1 GALEX intrinsic z2.0
# Processed 1P_p6_n1 GALEX intrinsic z1.5
# Processed 1P_p6_n1 GALEX intrinsic z1.0
# Processed 1P_p6_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p6_n1 UV1500 intrinsic z2.0
# Processed 1P_p6_n1 UV1500 intrinsic z1.5
# Processed 1P_p6_n1 UV1500 intrinsic z1.0
# Processed 1P_p6_n1 UV1500 intrinsic z0.1
# Processing 1P_p14_1
# Processing telescope: GALEX
# Processed 1P_p14_1 GALEX attenuated z2.0
# Processed 1P_p14_1 GALEX attenuated z1.5
# Processed 1P_p14_1 GALEX attenuated z1.0
# Processed 1P_p14_1 GALEX attenuated z0.1
# Processed 1P_p14_1 GALEX intrinsic z2.0
# Processed 1P_p14_1 GALEX intrinsic z1.5
# Processed 1P_p14_1 GALEX intrinsic z1.0
# Processed 1P_p14_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p14_1 UV1500 intrinsic z2.0
# Processed 1P_p14_1 UV1500 intrinsic z1.5
# Processed 1P_p14_1 UV1500 intrinsic z1.0
# Processed 1P_p14_1 UV1500 intrinsic z0.1
# Processing 1P_p25_n2
# Processing telescope: GALEX
# Processed 1P_p25_n2 GALEX attenuated z2.0
# Processed 1P_p25_n2 GALEX attenuated z1.5
# Processed 1P_p25_n2 GALEX attenuated z1.0
# Processed 1P_p25_n2 GALEX attenuated z0.1
# Processed 1P_p25_n2 GALEX intrinsic z2.0
# Processed 1P_p25_n2 GALEX intrinsic z1.5
# Processed 1P_p25_n2 GALEX intrinsic z1.0
# Processed 1P_p25_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p25_n2 UV1500 intrinsic z2.0
# Processed 1P_p25_n2 UV1500 intrinsic z1.5
# Processed 1P_p25_n2 UV1500 intrinsic z1.0
# Processed 1P_p25_n2 UV1500 intrinsic z0.1
# Processing 1P_p13_2
# Processing telescope: GALEX
# Processed 1P_p13_2 GALEX attenuated z2.0
# Processed 1P_p13_2 GALEX attenuated z1.5
# Processed 1P_p13_2 GALEX attenuated z1.0
# Processed 1P_p13_2 GALEX attenuated z0.1
# Processed 1P_p13_2 GALEX intrinsic z2.0
# Processed 1P_p13_2 GALEX intrinsic z1.5
# Processed 1P_p13_2 GALEX intrinsic z1.0
# Processed 1P_p13_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p13_2 UV1500 intrinsic z2.0
# Processed 1P_p13_2 UV1500 intrinsic z1.5
# Processed 1P_p13_2 UV1500 intrinsic z1.0
# Processed 1P_p13_2 UV1500 intrinsic z0.1
# Processing 1P_p12_n1
# Processing telescope: GALEX
# Processed 1P_p12_n1 GALEX attenuated z2.0
# Processed 1P_p12_n1 GALEX attenuated z1.5
# Processed 1P_p12_n1 GALEX attenuated z1.0
# Processed 1P_p12_n1 GALEX attenuated z0.1
# Processed 1P_p12_n1 GALEX intrinsic z2.0
# Processed 1P_p12_n1 GALEX intrinsic z1.5
# Processed 1P_p12_n1 GALEX intrinsic z1.0
# Processed 1P_p12_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p12_n1 UV1500 intrinsic z2.0
# Processed 1P_p12_n1 UV1500 intrinsic z1.5
# Processed 1P_p12_n1 UV1500 intrinsic z1.0
# Processed 1P_p12_n1 UV1500 intrinsic z0.1
# Processing 1P_p20_2
# Processing telescope: GALEX
# Processed 1P_p20_2 GALEX attenuated z2.0
# Processed 1P_p20_2 GALEX attenuated z1.5
# Processed 1P_p20_2 GALEX attenuated z1.0
# Processed 1P_p20_2 GALEX attenuated z0.1
# Processed 1P_p20_2 GALEX intrinsic z2.0
# Processed 1P_p20_2 GALEX intrinsic z1.5
# Processed 1P_p20_2 GALEX intrinsic z1.0
# Processed 1P_p20_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p20_2 UV1500 intrinsic z2.0
# Processed 1P_p20_2 UV1500 intrinsic z1.5
# Processed 1P_p20_2 UV1500 intrinsic z1.0
# Processed 1P_p20_2 UV1500 intrinsic z0.1
# Processing 1P_p18_1
# Processing telescope: GALEX
# Processed 1P_p18_1 GALEX attenuated z2.0
# Processed 1P_p18_1 GALEX attenuated z1.5
# Processed 1P_p18_1 GALEX attenuated z1.0
# Processed 1P_p18_1 GALEX attenuated z0.1
# Processed 1P_p18_1 GALEX intrinsic z2.0
# Processed 1P_p18_1 GALEX intrinsic z1.5
# Processed 1P_p18_1 GALEX intrinsic z1.0
# Processed 1P_p18_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p18_1 UV1500 intrinsic z2.0
# Processed 1P_p18_1 UV1500 intrinsic z1.5
# Processed 1P_p18_1 UV1500 intrinsic z1.0
# Processed 1P_p18_1 UV1500 intrinsic z0.1
# Processing 1P_p27_1
# Processing telescope: GALEX
# Processed 1P_p27_1 GALEX attenuated z2.0
# Processed 1P_p27_1 GALEX attenuated z1.5
# Processed 1P_p27_1 GALEX attenuated z1.0
# Processed 1P_p27_1 GALEX attenuated z0.1
# Processed 1P_p27_1 GALEX intrinsic z2.0
# Processed 1P_p27_1 GALEX intrinsic z1.5
# Processed 1P_p27_1 GALEX intrinsic z1.0
# Processed 1P_p27_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p27_1 UV1500 intrinsic z2.0
# Processed 1P_p27_1 UV1500 intrinsic z1.5
# Processed 1P_p27_1 UV1500 intrinsic z1.0
# Processed 1P_p27_1 UV1500 intrinsic z0.1
# Processing 1P_p13_1
# Processing telescope: GALEX
# Processed 1P_p13_1 GALEX attenuated z2.0
# Processed 1P_p13_1 GALEX attenuated z1.5
# Processed 1P_p13_1 GALEX attenuated z1.0
# Processed 1P_p13_1 GALEX attenuated z0.1
# Processed 1P_p13_1 GALEX intrinsic z2.0
# Processed 1P_p13_1 GALEX intrinsic z1.5
# Processed 1P_p13_1 GALEX intrinsic z1.0
# Processed 1P_p13_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p13_1 UV1500 intrinsic z2.0
# Processed 1P_p13_1 UV1500 intrinsic z1.5
# Processed 1P_p13_1 UV1500 intrinsic z1.0
# Processed 1P_p13_1 UV1500 intrinsic z0.1
# Processing 1P_p12_n2
# Processing telescope: GALEX
# Processed 1P_p12_n2 GALEX attenuated z2.0
# Processed 1P_p12_n2 GALEX attenuated z1.5
# Processed 1P_p12_n2 GALEX attenuated z1.0
# Processed 1P_p12_n2 GALEX attenuated z0.1
# Processed 1P_p12_n2 GALEX intrinsic z2.0
# Processed 1P_p12_n2 GALEX intrinsic z1.5
# Processed 1P_p12_n2 GALEX intrinsic z1.0
# Processed 1P_p12_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p12_n2 UV1500 intrinsic z2.0
# Processed 1P_p12_n2 UV1500 intrinsic z1.5
# Processed 1P_p12_n2 UV1500 intrinsic z1.0
# Processed 1P_p12_n2 UV1500 intrinsic z0.1
# Processing 1P_p25_n1
# Processing telescope: GALEX
# Processed 1P_p25_n1 GALEX attenuated z2.0
# Processed 1P_p25_n1 GALEX attenuated z1.5
# Processed 1P_p25_n1 GALEX attenuated z1.0
# Processed 1P_p25_n1 GALEX attenuated z0.1
# Processed 1P_p25_n1 GALEX intrinsic z2.0
# Processed 1P_p25_n1 GALEX intrinsic z1.5
# Processed 1P_p25_n1 GALEX intrinsic z1.0
# Processed 1P_p25_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p25_n1 UV1500 intrinsic z2.0
# Processed 1P_p25_n1 UV1500 intrinsic z1.5
# Processed 1P_p25_n1 UV1500 intrinsic z1.0
# Processed 1P_p25_n1 UV1500 intrinsic z0.1
# Processing 1P_p14_2
# Processing telescope: GALEX
# Processed 1P_p14_2 GALEX attenuated z2.0
# Processed 1P_p14_2 GALEX attenuated z1.5
# Processed 1P_p14_2 GALEX attenuated z1.0
# Processed 1P_p14_2 GALEX attenuated z0.1
# Processed 1P_p14_2 GALEX intrinsic z2.0
# Processed 1P_p14_2 GALEX intrinsic z1.5
# Processed 1P_p14_2 GALEX intrinsic z1.0
# Processed 1P_p14_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p14_2 UV1500 intrinsic z2.0
# Processed 1P_p14_2 UV1500 intrinsic z1.5
# Processed 1P_p14_2 UV1500 intrinsic z1.0
# Processed 1P_p14_2 UV1500 intrinsic z0.1
# Processing 1P_p6_n2
# Processing telescope: GALEX
# Processed 1P_p6_n2 GALEX attenuated z2.0
# Processed 1P_p6_n2 GALEX attenuated z1.5
# Processed 1P_p6_n2 GALEX attenuated z1.0
# Processed 1P_p6_n2 GALEX attenuated z0.1
# Processed 1P_p6_n2 GALEX intrinsic z2.0
# Processed 1P_p6_n2 GALEX intrinsic z1.5
# Processed 1P_p6_n2 GALEX intrinsic z1.0
# Processed 1P_p6_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p6_n2 UV1500 intrinsic z2.0
# Processed 1P_p6_n2 UV1500 intrinsic z1.5
# Processed 1P_p6_n2 UV1500 intrinsic z1.0
# Processed 1P_p6_n2 UV1500 intrinsic z0.1
# Processing 1P_p17_n1
# Processing telescope: GALEX
# Processed 1P_p17_n1 GALEX attenuated z2.0
# Processed 1P_p17_n1 GALEX attenuated z1.5
# Processed 1P_p17_n1 GALEX attenuated z1.0
# Processed 1P_p17_n1 GALEX attenuated z0.1
# Processed 1P_p17_n1 GALEX intrinsic z2.0
# Processed 1P_p17_n1 GALEX intrinsic z1.5
# Processed 1P_p17_n1 GALEX intrinsic z1.0
# Processed 1P_p17_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p17_n1 UV1500 intrinsic z2.0
# Processed 1P_p17_n1 UV1500 intrinsic z1.5
# Processed 1P_p17_n1 UV1500 intrinsic z1.0
# Processed 1P_p17_n1 UV1500 intrinsic z0.1
# Processing 1P_p8_1
# Processing telescope: GALEX
# Processed 1P_p8_1 GALEX attenuated z2.0
# Processed 1P_p8_1 GALEX attenuated z1.5
# Processed 1P_p8_1 GALEX attenuated z1.0
# Processed 1P_p8_1 GALEX attenuated z0.1
# Processed 1P_p8_1 GALEX intrinsic z2.0
# Processed 1P_p8_1 GALEX intrinsic z1.5
# Processed 1P_p8_1 GALEX intrinsic z1.0
# Processed 1P_p8_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p8_1 UV1500 intrinsic z2.0
# Processed 1P_p8_1 UV1500 intrinsic z1.5
# Processed 1P_p8_1 UV1500 intrinsic z1.0
# Processed 1P_p8_1 UV1500 intrinsic z0.1
# Processing 1P_p20_n2
# Processing telescope: GALEX
# Processed 1P_p20_n2 GALEX attenuated z2.0
# Processed 1P_p20_n2 GALEX attenuated z1.5
# Processed 1P_p20_n2 GALEX attenuated z1.0
# Processed 1P_p20_n2 GALEX attenuated z0.1
# Processed 1P_p20_n2 GALEX intrinsic z2.0
# Processed 1P_p20_n2 GALEX intrinsic z1.5
# Processed 1P_p20_n2 GALEX intrinsic z1.0
# Processed 1P_p20_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p20_n2 UV1500 intrinsic z2.0
# Processed 1P_p20_n2 UV1500 intrinsic z1.5
# Processed 1P_p20_n2 UV1500 intrinsic z1.0
# Processed 1P_p20_n2 UV1500 intrinsic z0.1
# Processing 1P_p3_n1
# Processing telescope: GALEX
# Processed 1P_p3_n1 GALEX attenuated z2.0
# Processed 1P_p3_n1 GALEX attenuated z1.5
# Processed 1P_p3_n1 GALEX attenuated z1.0
# Processed 1P_p3_n1 GALEX attenuated z0.1
# Processed 1P_p3_n1 GALEX intrinsic z2.0
# Processed 1P_p3_n1 GALEX intrinsic z1.5
# Processed 1P_p3_n1 GALEX intrinsic z1.0
# Processed 1P_p3_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p3_n1 UV1500 intrinsic z2.0
# Processed 1P_p3_n1 UV1500 intrinsic z1.5
# Processed 1P_p3_n1 UV1500 intrinsic z1.0
# Processed 1P_p3_n1 UV1500 intrinsic z0.1
# Processing 1P_p3_1
# Processing telescope: GALEX
# Processed 1P_p3_1 GALEX attenuated z2.0
# Processed 1P_p3_1 GALEX attenuated z1.5
# Processed 1P_p3_1 GALEX attenuated z1.0
# Processed 1P_p3_1 GALEX attenuated z0.1
# Processed 1P_p3_1 GALEX intrinsic z2.0
# Processed 1P_p3_1 GALEX intrinsic z1.5
# Processed 1P_p3_1 GALEX intrinsic z1.0
# Processed 1P_p3_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p3_1 UV1500 intrinsic z2.0
# Processed 1P_p3_1 UV1500 intrinsic z1.5
# Processed 1P_p3_1 UV1500 intrinsic z1.0
# Processed 1P_p3_1 UV1500 intrinsic z0.1
# Processing 1P_p4_2
# Processing telescope: GALEX
# Processed 1P_p4_2 GALEX attenuated z2.0
# Processed 1P_p4_2 GALEX attenuated z1.5
# Processed 1P_p4_2 GALEX attenuated z1.0
# Processed 1P_p4_2 GALEX attenuated z0.1
# Processed 1P_p4_2 GALEX intrinsic z2.0
# Processed 1P_p4_2 GALEX intrinsic z1.5
# Processed 1P_p4_2 GALEX intrinsic z1.0
# Processed 1P_p4_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p4_2 UV1500 intrinsic z2.0
# Processed 1P_p4_2 UV1500 intrinsic z1.5
# Processed 1P_p4_2 UV1500 intrinsic z1.0
# Processed 1P_p4_2 UV1500 intrinsic z0.1
# Processing 1P_p8_n1
# Processing telescope: GALEX
# Processed 1P_p8_n1 GALEX attenuated z2.0
# Processed 1P_p8_n1 GALEX attenuated z1.5
# Processed 1P_p8_n1 GALEX attenuated z1.0
# Processed 1P_p8_n1 GALEX attenuated z0.1
# Processed 1P_p8_n1 GALEX intrinsic z2.0
# Processed 1P_p8_n1 GALEX intrinsic z1.5
# Processed 1P_p8_n1 GALEX intrinsic z1.0
# Processed 1P_p8_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p8_n1 UV1500 intrinsic z2.0
# Processed 1P_p8_n1 UV1500 intrinsic z1.5
# Processed 1P_p8_n1 UV1500 intrinsic z1.0
# Processed 1P_p8_n1 UV1500 intrinsic z0.1
# Processing 1P_p1_n2
# Processing telescope: GALEX
# Processed 1P_p1_n2 GALEX attenuated z2.0
# Processed 1P_p1_n2 GALEX attenuated z1.5
# Processed 1P_p1_n2 GALEX attenuated z1.0
# Processed 1P_p1_n2 GALEX attenuated z0.1
# Processed 1P_p1_n2 GALEX intrinsic z2.0
# Processed 1P_p1_n2 GALEX intrinsic z1.5
# Processed 1P_p1_n2 GALEX intrinsic z1.0
# Processed 1P_p1_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p1_n2 UV1500 intrinsic z2.0
# Processed 1P_p1_n2 UV1500 intrinsic z1.5
# Processed 1P_p1_n2 UV1500 intrinsic z1.0
# Processed 1P_p1_n2 UV1500 intrinsic z0.1
# Processing 1P_p2_2
# Processing telescope: GALEX
# Processed 1P_p2_2 GALEX attenuated z2.0
# Processed 1P_p2_2 GALEX attenuated z1.5
# Processed 1P_p2_2 GALEX attenuated z1.0
# Processed 1P_p2_2 GALEX attenuated z0.1
# Processed 1P_p2_2 GALEX intrinsic z2.0
# Processed 1P_p2_2 GALEX intrinsic z1.5
# Processed 1P_p2_2 GALEX intrinsic z1.0
# Processed 1P_p2_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p2_2 UV1500 intrinsic z2.0
# Processed 1P_p2_2 UV1500 intrinsic z1.5
# Processed 1P_p2_2 UV1500 intrinsic z1.0
# Processed 1P_p2_2 UV1500 intrinsic z0.1
# Processing 1P_p5_1
# Processing telescope: GALEX
# Processed 1P_p5_1 GALEX attenuated z2.0
# Processed 1P_p5_1 GALEX attenuated z1.5
# Processed 1P_p5_1 GALEX attenuated z1.0
# Processed 1P_p5_1 GALEX attenuated z0.1
# Processed 1P_p5_1 GALEX intrinsic z2.0
# Processed 1P_p5_1 GALEX intrinsic z1.5
# Processed 1P_p5_1 GALEX intrinsic z1.0
# Processed 1P_p5_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p5_1 UV1500 intrinsic z2.0
# Processed 1P_p5_1 UV1500 intrinsic z1.5
# Processed 1P_p5_1 UV1500 intrinsic z1.0
# Processed 1P_p5_1 UV1500 intrinsic z0.1
# Processing 1P_p22_n1
# Processing telescope: GALEX
# Processed 1P_p22_n1 GALEX attenuated z2.0
# Processed 1P_p22_n1 GALEX attenuated z1.5
# Processed 1P_p22_n1 GALEX attenuated z1.0
# Processed 1P_p22_n1 GALEX attenuated z0.1
# Processed 1P_p22_n1 GALEX intrinsic z2.0
# Processed 1P_p22_n1 GALEX intrinsic z1.5
# Processed 1P_p22_n1 GALEX intrinsic z1.0
# Processed 1P_p22_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p22_n1 UV1500 intrinsic z2.0
# Processed 1P_p22_n1 UV1500 intrinsic z1.5
# Processed 1P_p22_n1 UV1500 intrinsic z1.0
# Processed 1P_p22_n1 UV1500 intrinsic z0.1
# Processing 1P_p9_2
# Processing telescope: GALEX
# Processed 1P_p9_2 GALEX attenuated z2.0
# Processed 1P_p9_2 GALEX attenuated z1.5
# Processed 1P_p9_2 GALEX attenuated z1.0
# Processed 1P_p9_2 GALEX attenuated z0.1
# Processed 1P_p9_2 GALEX intrinsic z2.0
# Processed 1P_p9_2 GALEX intrinsic z1.5
# Processed 1P_p9_2 GALEX intrinsic z1.0
# Processed 1P_p9_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p9_2 UV1500 intrinsic z2.0
# Processed 1P_p9_2 UV1500 intrinsic z1.5
# Processed 1P_p9_2 UV1500 intrinsic z1.0
# Processed 1P_p9_2 UV1500 intrinsic z0.1
# Processing 1P_p12_2
# Processing telescope: GALEX
# Processed 1P_p12_2 GALEX attenuated z2.0
# Processed 1P_p12_2 GALEX attenuated z1.5
# Processed 1P_p12_2 GALEX attenuated z1.0
# Processed 1P_p12_2 GALEX attenuated z0.1
# Processed 1P_p12_2 GALEX intrinsic z2.0
# Processed 1P_p12_2 GALEX intrinsic z1.5
# Processed 1P_p12_2 GALEX intrinsic z1.0
# Processed 1P_p12_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p12_2 UV1500 intrinsic z2.0
# Processed 1P_p12_2 UV1500 intrinsic z1.5
# Processed 1P_p12_2 UV1500 intrinsic z1.0
# Processed 1P_p12_2 UV1500 intrinsic z0.1
# Processing 1P_p15_1
# Processing telescope: GALEX
# Processed 1P_p15_1 GALEX attenuated z2.0
# Processed 1P_p15_1 GALEX attenuated z1.5
# Processed 1P_p15_1 GALEX attenuated z1.0
# Processed 1P_p15_1 GALEX attenuated z0.1
# Processed 1P_p15_1 GALEX intrinsic z2.0
# Processed 1P_p15_1 GALEX intrinsic z1.5
# Processed 1P_p15_1 GALEX intrinsic z1.0
# Processed 1P_p15_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p15_1 UV1500 intrinsic z2.0
# Processed 1P_p15_1 UV1500 intrinsic z1.5
# Processed 1P_p15_1 UV1500 intrinsic z1.0
# Processed 1P_p15_1 UV1500 intrinsic z0.1
# Processing 1P_p19_2
# Processing telescope: GALEX
# Processed 1P_p19_2 GALEX attenuated z2.0
# Processed 1P_p19_2 GALEX attenuated z1.5
# Processed 1P_p19_2 GALEX attenuated z1.0
# Processed 1P_p19_2 GALEX attenuated z0.1
# Processed 1P_p19_2 GALEX intrinsic z2.0
# Processed 1P_p19_2 GALEX intrinsic z1.5
# Processed 1P_p19_2 GALEX intrinsic z1.0
# Processed 1P_p19_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p19_2 UV1500 intrinsic z2.0
# Processed 1P_p19_2 UV1500 intrinsic z1.5
# Processed 1P_p19_2 UV1500 intrinsic z1.0
# Processed 1P_p19_2 UV1500 intrinsic z0.1
# Processing 1P_p21_1
# Processing telescope: GALEX
# Processed 1P_p21_1 GALEX attenuated z2.0
# Processed 1P_p21_1 GALEX attenuated z1.5
# Processed 1P_p21_1 GALEX attenuated z1.0
# Processed 1P_p21_1 GALEX attenuated z0.1
# Processed 1P_p21_1 GALEX intrinsic z2.0
# Processed 1P_p21_1 GALEX intrinsic z1.5
# Processed 1P_p21_1 GALEX intrinsic z1.0
# Processed 1P_p21_1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p21_1 UV1500 intrinsic z2.0
# Processed 1P_p21_1 UV1500 intrinsic z1.5
# Processed 1P_p21_1 UV1500 intrinsic z1.0
# Processed 1P_p21_1 UV1500 intrinsic z0.1
# Processing 1P_p4_n1
# Processing telescope: GALEX
# Processed 1P_p4_n1 GALEX attenuated z2.0
# Processed 1P_p4_n1 GALEX attenuated z1.5
# Processed 1P_p4_n1 GALEX attenuated z1.0
# Processed 1P_p4_n1 GALEX attenuated z0.1
# Processed 1P_p4_n1 GALEX intrinsic z2.0
# Processed 1P_p4_n1 GALEX intrinsic z1.5
# Processed 1P_p4_n1 GALEX intrinsic z1.0
# Processed 1P_p4_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p4_n1 UV1500 intrinsic z2.0
# Processed 1P_p4_n1 UV1500 intrinsic z1.5
# Processed 1P_p4_n1 UV1500 intrinsic z1.0
# Processed 1P_p4_n1 UV1500 intrinsic z0.1
# Processing 1P_p10_n1
# Processing telescope: GALEX
# Processed 1P_p10_n1 GALEX attenuated z2.0
# Processed 1P_p10_n1 GALEX attenuated z1.5
# Processed 1P_p10_n1 GALEX attenuated z1.0
# Processed 1P_p10_n1 GALEX attenuated z0.1
# Processed 1P_p10_n1 GALEX intrinsic z2.0
# Processed 1P_p10_n1 GALEX intrinsic z1.5
# Processed 1P_p10_n1 GALEX intrinsic z1.0
# Processed 1P_p10_n1 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p10_n1 UV1500 intrinsic z2.0
# Processed 1P_p10_n1 UV1500 intrinsic z1.5
# Processed 1P_p10_n1 UV1500 intrinsic z1.0
# Processed 1P_p10_n1 UV1500 intrinsic z0.1
# Processing 1P_p26_2
# Processing telescope: GALEX
# Processed 1P_p26_2 GALEX attenuated z2.0
# Processed 1P_p26_2 GALEX attenuated z1.5
# Processed 1P_p26_2 GALEX attenuated z1.0
# Processed 1P_p26_2 GALEX attenuated z0.1
# Processed 1P_p26_2 GALEX intrinsic z2.0
# Processed 1P_p26_2 GALEX intrinsic z1.5
# Processed 1P_p26_2 GALEX intrinsic z1.0
# Processed 1P_p26_2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p26_2 UV1500 intrinsic z2.0
# Processed 1P_p26_2 UV1500 intrinsic z1.5
# Processed 1P_p26_2 UV1500 intrinsic z1.0
# Processed 1P_p26_2 UV1500 intrinsic z0.1
# Processing 1P_p19_n2
# Processing telescope: GALEX
# Processed 1P_p19_n2 GALEX attenuated z2.0
# Processed 1P_p19_n2 GALEX attenuated z1.5
# Processed 1P_p19_n2 GALEX attenuated z1.0
# Processed 1P_p19_n2 GALEX attenuated z0.1
# Processed 1P_p19_n2 GALEX intrinsic z2.0
# Processed 1P_p19_n2 GALEX intrinsic z1.5
# Processed 1P_p19_n2 GALEX intrinsic z1.0
# Processed 1P_p19_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p19_n2 UV1500 intrinsic z2.0
# Processed 1P_p19_n2 UV1500 intrinsic z1.5
# Processed 1P_p19_n2 UV1500 intrinsic z1.0
# Processed 1P_p19_n2 UV1500 intrinsic z0.1
# Processing 1P_p27_n2
# Processing telescope: GALEX
# Processed 1P_p27_n2 GALEX attenuated z2.0
# Processed 1P_p27_n2 GALEX attenuated z1.5
# Processed 1P_p27_n2 GALEX attenuated z1.0
# Processed 1P_p27_n2 GALEX attenuated z0.1
# Processed 1P_p27_n2 GALEX intrinsic z2.0
# Processed 1P_p27_n2 GALEX intrinsic z1.5
# Processed 1P_p27_n2 GALEX intrinsic z1.0
# Processed 1P_p27_n2 GALEX intrinsic z0.1
# Processing telescope: UV1500
# Processed 1P_p27_n2 UV1500 intrinsic z2.0
# Processed 1P_p27_n2 UV1500 intrinsic z1.5
# Processed 1P_p27_n2 UV1500 intrinsic z1.0
# Processed 1P_p27_n2 UV1500 intrinsic z0.1
# Processing complete!
