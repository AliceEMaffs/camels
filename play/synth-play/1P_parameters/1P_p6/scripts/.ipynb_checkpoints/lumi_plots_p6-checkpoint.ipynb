# %%
# Python script to plot magi.qdp

import matplotlib.pyplot as plt
from matplotlib import rc

# Open the .qdp file
def get_arnouts(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Initialize lists to store x and y values
    arn_x = []
    arn_y = []

    # Read data between 'no no no' lines
    start_index = lines.index(' no no no no\n') + 1
    end_index = lines.index(' no no no no\n', start_index)

    for line in lines[start_index:end_index]:
        # Split the line and extract x and y values
        parts = line.strip().split()
        arn_x.append(float(parts[0]))
        arn_y.append(float(parts[1]))

    return arn_x, arn_y


arn_x, arn_y = get_arnouts('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p6/outfiles/magi_1P_p6_1.qdp')

# %%
# Python script to plot magi.qdp

import matplotlib.pyplot as plt
# XMM
def get_data_from_magi(filename):
    

    # Open the .qdp file
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Initialize lists to store x and y values
    x = []
    y = []

    # Find the index of the start and end lines
    start_index = lines.index('   -22.00000  no no no\n') + 1
    end_index = lines.index(' no no no no\n', start_index)

    # Read data between start and end lines
    for line in lines[start_index:end_index]:
        # Split the line and extract x and y values
        parts = line.strip().split()
        x.append(float(parts[0]))
        y.append(float(parts[1]))
        
    return x, y

x_p6_1,y_p6_1 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p6/outfiles/magi_1P_p6_1.qdp')
x_p6_2,y_p6_2= get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p6/outfiles/magi_1P_p6_2.qdp')
x_p6_n1,y_p6_n1 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p6/outfiles/magi_1P_p6_n1.qdp')
x_p6_n2,y_p6_n2 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p6/outfiles/magi_1P_p6_n2.qdp')

# %%
print(arn_x)
# Out:
# [-24.22915, -23.97915, -23.72915, -23.47915, -23.22915, -22.97915, -22.72915, -22.47915, -22.22915, -21.97915, -21.72915, -21.47915, -21.22915, -20.97915, -20.72915, -20.47915, -20.22915, -19.97915, -19.72915, -19.47915, -19.22915, -18.97915, -18.72915, -18.47915, -18.22915, -17.97915, -17.72915, -17.47915, -17.22915, -16.97915, -16.72915, -16.47915, -16.22915, -15.97915, -15.72915, -15.47915, -15.22915, -14.97915, -14.72915, -14.47915, -14.22915, -13.97915, -13.72915, -13.47915, -13.22915, -12.97915, -12.72915, -12.47915, -12.22915, -11.97915, -11.72915, -11.47915, -11.22915, -10.97915, -10.72915, -10.47915, -10.22915, -9.97915, -9.72915, -9.47915, -9.22915, -8.97915, -8.72915, -8.47915, -8.22915, -7.97915, -7.72915, -7.47915, -7.22915, -6.97915, -6.72915, -6.47915, -6.22915, -5.97915, -5.72915, -5.47915, -5.22915, -4.97915, -4.72915, -4.47915, -4.22915, -3.97915, -3.72915, -3.47915, -3.22915, -2.97915, -2.72915, -2.47915, -2.22915, -1.97915, -1.72915, -1.47915, -1.22915, -0.97915, 
# ...

# %%
print(arn_y)
# Out:
# [-38.00489, -30.92518, -25.29034, -20.80312, -17.22752, -14.37598, -12.09962, -10.28012, -8.82353, -7.65522, -6.71588, -5.95842, -5.34544, -4.84722, -4.44016, -4.1055, -3.82837, -3.59692, -3.40176, -3.23543, -3.09199, -2.96675, -2.85595, -2.75663, -2.66642, -2.58346, -2.50624, -2.4336, -2.36458, -2.29845, -2.23461, -2.17258, -2.112, -2.05257, -1.99405, -1.93625, -1.87903, -1.82227, -1.76586, -1.70975, -1.65387, -1.59816, -1.54261, -1.48716, -1.43181, -1.37653, -1.32131, -1.26613, -1.21099, -1.15588, -1.10079, -1.04572, -0.99067, -0.93562, -0.88059, -0.82556, -0.77054, -0.71552, -0.66051, -0.60549, -0.55049, -0.49548, -0.44047, -0.38547, -0.33046, -0.27546, -0.22046, -0.16546, -0.11046, -0.05546, -0.00045, 0.05455, 0.10955, 0.16455, 0.21955, 0.27455, 0.32955, 0.38455, 0.43955, 0.49455, 0.54955, 0.60455, 0.65955, 0.71455, 0.76955, 0.82455, 0.87955, 0.93455, 0.98955, 1.04455, 1.09955, 1.15455, 1.20955, 1.26455, 1.31955, 1.37455, 1.42955, 1.48455, 1.53955, 1.59455, 1.64955, 1.70455, 1.75
# ...

# %%
print(x_p6_1)
# Out:
# [-21.42196, -20.92196, -20.42196, -19.92196, -19.42196, -18.92196, -18.42196, -17.92196]

# %%
print(y_p6_1)
# Out:
# [-3.99129, -3.44722, -3.63911, -3.16199, -3.04473, -2.8887, -2.71555, -2.13853]

# %%
print(x_p6_2)
# Out:
# [-21.92196, -21.42196, -20.92196, -20.42196, -19.92196, -19.42196, -18.92196, -18.42196, -17.92196]

# %%
print(y_p6_2)
# Out:
# [-4.59335, -3.89438, -3.47941, -3.38923, -3.23162, -3.00902, -2.93445, -2.77769, -2.08053]

# %%
# this is the first half of the magi.qdp files.
# Plot the data
plt.plot(x_p6_1, y_p6_1, marker='o', markersize=3, linestyle='-',color='blue',label='$A_{AGN2} = 28.28$')
plt.plot(x_p6_2, y_p6_2, marker='o', markersize=3, linestyle='-',color='green',label='$A_{AGN2} = 40$')
plt.plot(x_p6_n1, y_p6_n1, marker='o', markersize=3, linestyle='-',color='red',label='$A_{AGN2} = 14.14$')
plt.plot(x_p6_n2, y_p6_n2, marker='o', markersize=3, linestyle='-',color='orange',label='$A_{AGN2} = 10$')
plt.plot(arn_x, arn_y,color='black', label='Arnouts et al 2005')
plt.xlabel('M')

# Set x and y limits
plt.xlim(-22.5, -17.7)
plt.ylim(-7, -1)

plt.ylabel('Phi')
plt.title('LF at z=0.475 with varying AGN FB \nkinetic mode burstiness, $A_{AGN2}$')
plt.grid(True)

# Add a legend
plt.legend(loc='lower right')
plt.text(-22, -2, '$A_{AGN2}$', fontsize = 22)

plt.show()

# %% [markdown]
# Arnouts parameters:
# We are using 0.4 < z < 0.6
#
# So parameters are:
# alpha: -1.55
# M*   : -19.49
# Phi*  : 1.69E-03
# ![image.png](attachment:image.png)
