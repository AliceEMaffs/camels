# %%
# Python script to plot magi.qdp

import matplotlib.pyplot as plt

# Open the .qdp file
def get_arnouts(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Initialize lists to store x and y values
    arn_x = []
    arn_y = []

    # Read data between 'no no no' lines
    start_index = lines.index(' no no no no\n') + 1
    end_index = lines.index(' no no no no\n', start_index)

    for line in lines[start_index:end_index]:
        # Split the line and extract x and y values
        parts = line.strip().split()
        arn_x.append(float(parts[0]))
        arn_y.append(float(parts[1]))

    return arn_x, arn_y


arn_x, arn_y = get_arnouts('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p1/outfiles/magi_p1_0.qdp')

# %%
# Python script to plot magi.qdp

import matplotlib.pyplot as plt
# XMM
def get_data_from_magi(filename):
    

    # Open the .qdp file
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Initialize lists to store x and y values
    x = []
    y = []

    # Find the index of the start and end lines
    start_index = lines.index('   -22.00000  no no no\n') + 1
    end_index = lines.index(' no no no no\n', start_index)

    # Read data between start and end lines
    for line in lines[start_index:end_index]:
        # Split the line and extract x and y values
        parts = line.strip().split()
        x.append(float(parts[0]))
        y.append(float(parts[1]))
        
    return x, y

x_p1_0,y_p1_0 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p1/outfiles/magi_p1_0.qdp')
x_p1_1,y_p1_1 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p1/outfiles/magi_p1_1.qdp')
x_p1_n1,y_p1_n1 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p1/outfiles/magi_p1_n1.qdp')
x_p1_n2,y_p1_n2 = get_data_from_magi('/home/jovyan/camels/play/synth-play/1P_parameters/1P_p1/outfiles/magi_p1_n2.qdp')

# %%
print(arn_x)
# Out:
# [-24.22915, -23.97915, -23.72915, -23.47915, -23.22915, -22.97915, -22.72915, -22.47915, -22.22915, -21.97915, -21.72915, -21.47915, -21.22915, -20.97915, -20.72915, -20.47915, -20.22915, -19.97915, -19.72915, -19.47915, -19.22915, -18.97915, -18.72915, -18.47915, -18.22915, -17.97915, -17.72915, -17.47915, -17.22915, -16.97915, -16.72915, -16.47915, -16.22915, -15.97915, -15.72915, -15.47915, -15.22915, -14.97915, -14.72915, -14.47915, -14.22915, -13.97915, -13.72915, -13.47915, -13.22915, -12.97915, -12.72915, -12.47915, -12.22915, -11.97915, -11.72915, -11.47915, -11.22915, -10.97915, -10.72915, -10.47915, -10.22915, -9.97915, -9.72915, -9.47915, -9.22915, -8.97915, -8.72915, -8.47915, -8.22915, -7.97915, -7.72915, -7.47915, -7.22915, -6.97915, -6.72915, -6.47915, -6.22915, -5.97915, -5.72915, -5.47915, -5.22915, -4.97915, -4.72915, -4.47915, -4.22915, -3.97915, -3.72915, -3.47915, -3.22915, -2.97915, -2.72915, -2.47915, -2.22915, -1.97915, -1.72915, -1.47915, -1.22915, -0.97915, -0.72915, -0.47915, -0.22915, 0.02085, 0.27085, 0.52085, 0.77085, 1.02085, 1.27085, 1.52085, 1.77085, 2.02085, 2.27085, 2.52085, 2.77085, 3.02085, 3.27085, 3.52085, 3.77085, 4.02085, 4.27085, 4.52085, 4.77085, 5.02085, 5.27085, 5.52085, 5.77085, 6.02085, 6.27085, 6.52085, 6.77085, 7.02085, 7.27085, 7.52085, 7.77085, 8.02085, 8.27085, 8.52085, 8.77085, 9.02085, 9.27085, 9.52085, 9.77085, 10.02085, 10.27085, 10.52085, 10.77085, 11.02085, 11.27085, 11.52085]

# %%
print(arn_y)
# Out:
# [-38.00489, -30.92518, -25.29034, -20.80312, -17.22752, -14.37598, -12.09962, -10.28012, -8.82353, -7.65522, -6.71588, -5.95842, -5.34544, -4.84722, -4.44016, -4.1055, -3.82837, -3.59692, -3.40176, -3.23543, -3.09199, -2.96675, -2.85595, -2.75663, -2.66642, -2.58346, -2.50624, -2.4336, -2.36458, -2.29845, -2.23461, -2.17258, -2.112, -2.05257, -1.99405, -1.93625, -1.87903, -1.82227, -1.76586, -1.70975, -1.65387, -1.59816, -1.54261, -1.48716, -1.43181, -1.37653, -1.32131, -1.26613, -1.21099, -1.15588, -1.10079, -1.04572, -0.99067, -0.93562, -0.88059, -0.82556, -0.77054, -0.71552, -0.66051, -0.60549, -0.55049, -0.49548, -0.44047, -0.38547, -0.33046, -0.27546, -0.22046, -0.16546, -0.11046, -0.05546, -0.00045, 0.05455, 0.10955, 0.16455, 0.21955, 0.27455, 0.32955, 0.38455, 0.43955, 0.49455, 0.54955, 0.60455, 0.65955, 0.71455, 0.76955, 0.82455, 0.87955, 0.93455, 0.98955, 1.04455, 1.09955, 1.15455, 1.20955, 1.26455, 1.31955, 1.37455, 1.42955, 1.48455, 1.53955, 1.59455, 1.64955, 1.70455, 1.75955, 1.81455, 1.86955, 1.92455, 1.97955, 2.03455, 2.08955, 2.14455, 2.19955, 2.25455, 2.30955, 2.36455, 2.41955, 2.47455, 2.52955, 2.58455, 2.63955, 2.69455, 2.74955, 2.80455, 2.85955, 2.91455, 2.96955, 3.02455, 3.07955, 3.13455, 3.18955, 3.24455, 3.29955, 3.35455, 3.40955, 3.46455, 3.51955, 3.57455, 3.62955, 3.68455, 3.73955, 3.79455, 3.84955, 3.90455, 3.95955, 4.01455]

# %%
print(x_p1_0)
# Out:
# [-21.92196, -21.42196, -20.92196, -20.42196, -19.92196, -19.42196, -18.92196, -18.42196, -17.92196]

# %%
print(y_p1_0)
# Out:
# [-4.59335, -3.99129, -3.69026, -3.51417, -3.14619, -2.8728, -3.16854, -2.68752, -2.15432]

# %%
print(x_p1_1)
# Out:
# [-21.42196, -20.92196, -20.42196, -19.92196, -19.42196, -18.92196, -18.42196, -17.92196]

# %%
print(y_p1_1)
# Out:
# [-4.29232, -3.99129, -3.27113, -3.03705, -2.98674, -2.85729, -2.61288, -2.26347]

# %%
# this is the first half of the magi.qdp files.
# Plot the data
plt.plot(x_p1_0, y_p1_0, marker='o', markersize=3, linestyle='-',color='blue',label='$\Omega_{m}$=0.3')
plt.plot(x_p1_1, y_p1_1, marker='o', markersize=3, linestyle='-',color='green',label='$\Omega_{m}$=0.4')
plt.plot(x_p1_n1, y_p1_n1, marker='o', markersize=3, linestyle='-',color='red',label='$\Omega_{m}$=0.2')
plt.plot(x_p1_n2, y_p1_n2, marker='o', markersize=3, linestyle='-',color='orange',label='$\Omega_{m}$=0.1')
plt.plot(arn_x, arn_y,color='black', label='Arnouts et al 2005')
plt.xlabel('M')

# Set x and y limits
plt.xlim(-22.5, -18.5)
plt.ylim(-7, -1)

plt.ylabel('Phi')
plt.title('Arnouts vs 1P_p1 parameters')
plt.grid(True)

# Add a legend
plt.legend(loc='lower right')

plt.show()

# %% [markdown]
# Arnouts parameters:
# We are using 0.4 < z < 0.6
#
# So parameters are:
# alpha: -1.55
# M*   : -19.49
# Phi*  : 1.69E-03
# ![image.png](attachment:image.png)

# %% [markdown]
# # UVOT plot with Schechter function

# %%
def get_schechter_fit(out_file, x):
    # Open the file and read the lines
    with open(out_file, 'r') as file:
        lines = file.readlines()

    # Strip any leading/trailing whitespace and newline characters
    lines = [line.strip() for line in lines]

    # Assign the values to variables
    Phistar = float(lines[0])
    value2 = float(lines[1])
    Alpha = float(lines[2])
    value4 = float(lines[3])
    Mstar = float(lines[4])

    # Assign the characters as variables
    char1 = lines[5]
    char2 = lines[6]
    char3 = lines[7]

    # Print the variables (optional)
    print("Values:")
    print("Phi *:", Phistar) # Phi * (Units Mpc -3)
    #print("Value 2:", value2) # dummy - ignore
    print("alpha:", Alpha) # alpha
    #print("Value 4:", value4) # dummy - ignore
    print("M*:", Mstar) # M*
    
    # Define the range of magnitudes for plotting
    # Define the range of magnitudes for plotting using the min and max of your x_uvot data
    mag_min = np.min(x)
    mag_max = np.max(x)
    mag_range = np.linspace(-15, -25, 100)

    # Define the Schechter function using Astropy's Schechter1D model
    schechter_model = Schechter1D(Phistar, Mstar, Alpha)

    # Evaluate the Schechter function over the range of magnitudes
    phi_values = schechter_model(mag_range)
    
    return phi_values, mag_range

# %%
phi_values_p1_0, mag_range_p1_0 = get_schechter_fit('/home/jovyan/camels/play/synth-play/1P_parameters/out_p1_0.law', x_p1_0)
phi_values_p1_1, mag_range_p1_1 = get_schechter_fit('/home/jovyan/camels/play/synth-play/1P_parameters/out_p1_1.law', x_p1_1)
# Out:
# Values:
# Phi *: 8.75164696e-05
# alpha: -1.98826957
# M*: -22.2060394
# Values:
# Phi *: 0.000553963066
# alpha: -1.76219058
# M*: -20.9039612

# %%
phi_values_p1_0
# Out:
# array([5.68067467e-02, 5.18100874e-02, 4.72523399e-02, 4.30949493e-02,
#        3.93027474e-02, 3.58436553e-02, 3.26884119e-02, 2.98103265e-02,
#        2.71850532e-02, 2.47903844e-02, 2.26060635e-02, 2.06136132e-02,
#        1.87961794e-02, 1.71383883e-02, 1.56262169e-02, 1.42468739e-02,
#        1.29886916e-02, 1.18410272e-02, 1.07941730e-02, 9.83927395e-03,
#        8.96825294e-03, 8.17374238e-03, 7.44902193e-03, 6.78796163e-03,
#        6.18497005e-03, 5.63494697e-03, 5.13324027e-03, 4.67560653e-03,
#        4.25817519e-03, 3.87741576e-03, 3.53010797e-03, 3.21331453e-03,
#        2.92435628e-03, 2.66078954e-03, 2.42038539e-03, 2.20111089e-03,
#        2.00111180e-03, 1.81869695e-03, 1.65232389e-03, 1.50058590e-03,
#        1.36220001e-03, 1.23599620e-03, 1.12090746e-03, 1.01596080e-03,
#        9.20268983e-04, 8.33022997e-04, 7.53485241e-04, 6.80983248e-04,
#        6.14903986e-04, 5.54688660e-04, 4.99827962e-04, 4.49857741e-04,
#        4.04355044e-04, 3.62934515e-04, 3.25245088e-04, 2.90966979e-04,
#        2.59808928e-04, 2.31505676e-04, 2.05815652e-04, 1.82518855e-04,
#        1.61414903e-04, 1.42321241e-04, 1.25071487e-04, 1.09513899e-04,
#        9.55099666e-05, 8.29330901e-05, 7.16673637e-05, 6.16064377e-05,
#        5.26524622e-05, 4.47151064e-05, 3.77106521e-05, 3.15611628e-05,
#        2.61937302e-05, 2.15398048e-05, 1.75346154e-05, 1.41166869e-05,
#        1.12274630e-05, 8.81104164e-06, 6.81402677e-06, 5.18549722e-06,
#        3.87708612e-06, 2.84315800e-06, 2.04106182e-06, 1.43142966e-06,
#        9.78484140e-07, 6.50312835e-07, 4.19068141e-07, 2.61055989e-07,
#        1.56687677e-07, 9.02846248e-08, 4.97442205e-08, 2.60930578e-08,
#        1.29681965e-08, 6.07466413e-09, 2.66652808e-09, 1.08993339e-09,
#        4.11968596e-10, 1.42897515e-10, 4.51070678e-11, 1.28390300e-11])

# %%
# Try plotting the Schechter function in analytical form:
import numpy as np
import matplotlib.pyplot as plt
from astropy.modeling.models import Schechter1D

# Plot the Schechter function
plt.plot(mag_range_p1_0, np.log10(phi_values_p1_0),color='navy')
plt.scatter(x_p1_0, y_p1_0, marker='o',color='navy',label='1P_p1_0')
plt.plot(mag_range_p1_1, np.log10(phi_values_p1_1),color='red')
plt.scatter(x_p1_1, y_p1_1, marker='o',color='red',label='1P_p1_1')

plt.xlabel('Mag')
plt.ylabel('$log_{10} [ \Phi (Mpc^{-3} mag^{-1} )]$')
plt.title('Schechter Function')
plt.ylim(-7,-1)
plt.xlim(-25, -15)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # XMM Plot with Schechter Function

# %%
# Open the file and read the lines
with open('out_om.law', 'r') as file:
    lines = file.readlines()

# Strip any leading/trailing whitespace and newline characters
lines = [line.strip() for line in lines]

# Assign the values to variables
Phistar_om = float(lines[0])
value2 = float(lines[1])
Alpha_om = float(lines[2])
value4 = float(lines[3])
Mstar_om = float(lines[4])

# Assign the characters as variables
char1 = lines[5]
char2 = lines[6]
char3 = lines[7]

# Print the variables (optional)
print("Values:")
print("Phi *:", Phistar_om) # Phi * (Units Mpc -3)
#print("Value 2:", value2) # dummy - ignore
print("alpha:", Alpha_om) # alpha
#print("Value 4:", value4) # dummy - ignore
print("M*:", Mstar_om) # M*

# Try plotting the Schechter function in analytical form:
import numpy as np
import matplotlib.pyplot as plt
from astropy.modeling.models import Schechter1D

# Define the range of magnitudes for plotting
# Define the range of magnitudes for plotting using the min and max of your x_uvot data
mag_min = np.min(x_xmm)
mag_max = np.max(x_xmm)
mag_range = np.linspace(-15, -25, 100)


# Define the Schechter function using Astropy's Schechter1D model
schechter_model_om = Schechter1D(Phistar_om, Mstar_om, Alpha_om)

# Evaluate the Schechter function over the range of magnitudes
phi_values_om = schechter_model_om(mag_range)

# Plot the Schechter function
plt.plot(mag_range, np.log10(phi_values_om),color='darkgreen', label='Schechter Function')
plt.scatter(x_xmm, y_xmm, marker='o',color='darkgreen',label='XMM-OM camels')

plt.xlabel('Magnitude (M)')
plt.ylabel('Phi (Mpc^-3)')
plt.title('Schechter Function')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Values:
# Phi *: 5.59150476e-06
# alpha: -2.38333201
# M*: -23.3788795

# %% [markdown]
# # Tophat plot with Schechter Function

# %%
# Open the file and read the lines
with open('out_th.law', 'r') as file:
    lines = file.readlines()

# Strip any leading/trailing whitespace and newline characters
lines = [line.strip() for line in lines]

# Assign the values to variables
Phistar_th = float(lines[0])
value2 = float(lines[1])
Alpha_th = float(lines[2])
value4 = float(lines[3])
Mstar_th = float(lines[4])

# Assign the characters as variables
char1 = lines[5]
char2 = lines[6]
char3 = lines[7]

# Print the variables (optional)
print("Values:")
print("Phi *:", Phistar_th) # Phi * (Units Mpc -3)
#print("Value 2:", value2) # dummy - ignore
print("alpha:", Alpha_th) # alpha
#print("Value 4:", value4) # dummy - ignore
print("M*:", Mstar_th) # M*

# Try plotting the Schechter function in analytical form:
import numpy as np
import matplotlib.pyplot as plt
from astropy.modeling.models import Schechter1D

# Define the range of magnitudes for plotting
# Define the range of magnitudes for plotting using the min and max of your x_uvot data
mag_min = np.min(x_th)
mag_max = np.max(x_th)
mag_range = np.linspace(-15, -25, 100)


# Define the Schechter function using Astropy's Schechter1D model
schechter_model_th = Schechter1D(Phistar_th, Mstar_th, Alpha_th)

# Evaluate the Schechter function over the range of magnitudes
phi_values_th = schechter_model_th(mag_range)

# Plot the Schechter function
plt.plot(mag_range, np.log10(phi_values_th),color='orchid')
plt.scatter(x_th, y_th, marker='o',color='orchid',label='tophat camels')

# plot arnouts:
plt.plot(arn_x, arn_y, linestyle='-',color='black', label='Arnouts et al 2005')

# Set x and y limits
plt.xlim(-26, -15)
plt.ylim(-8, -1)

plt.xlabel('Magnitude (M)')
plt.ylabel('Phi (Mpc^-3)')
plt.title('UVLF for CAMELS at z=0.465')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Values:
# Phi *: 8.75164696e-05
# alpha: -1.98826957
# M*: -22.2060394

# %%
# Plot the TH
plt.plot(mag_range, np.log10(phi_values_th),color='orchid')#, label='Schechter Function')
plt.scatter(x_th, y_th, marker='o',color='orchid',label='Tophat camels')
# Plot the XMM
plt.plot(mag_range, np.log10(phi_values_om),color='olive')#, label='Schechter Function')
plt.scatter(x_xmm, y_xmm, marker='o',color='olive',label='XMM-OM camels')
# Plot uvot
plt.plot(mag_range, np.log10(phi_values_uvot),color='navy')#, label='Schechter Function')
plt.scatter(x_uvot, y_uvot, marker='o',color='navy',label='UVOT camels')
# plot arnouts:
plt.plot(arn_x, arn_y, linestyle='-',color='black', label='Arnouts et al 2005')

# Set x and y limits
plt.xlim(-25, -15)
plt.ylim(-7, -1)


plt.xlabel('Magnitude (M)')
plt.ylabel('Phi (Mpc^-3)')
plt.title('Estimated UVLF for CAMELS at z=0.465')
plt.legend()
plt.grid(True)
plt.show()
